# %%
import backtrader as bt
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

from backtesting import Backtest, Strategy
from backtesting.lib import crossover

# %%
# class VWAP(bt.Indicator):
#     lines = ('vwap',)
#     plotinfo = dict(subplot=False)
    
#     def next(self):
#         # Calculate cumulative sum of price*volume and volume up to the current bar
#         total_pv = sum(self.data.close[i] * self.data.volume[i] for i in range(len(self.data)))
#         total_vol = sum(self.data.volume[i] for i in range(len(self.data)))
#         self.lines.vwap[0] = total_pv / total_vol if total_vol != 0 else self.data.close[0]


class VWAPRollingIndicator(bt.Indicator):
    """
    Volume Weighted Average Price (VWAP) indicator, rolling calculation.
    """

    lines = ("vwap_rolling",)
    params = {"period": 14}
    plotinfo = {"subplot": False}
    plotlines = {"vwap_rolling": {"color": "green"}}

    def __init__(self) -> None:
        self.hlc = (self.data.high + self.data.low + self.data.close) / 3.0
        self.hlc_volume_sum = bt.ind.SumN(self.hlc * self.data.volume, period=self.p.period)
        self.volume_sum = bt.ind.SumN(self.data.volume, period=self.p.period)

        self.lines.vwap_rolling = bt.DivByZero(self.hlc_volume_sum, self.volume_sum, None) 


        
class VWAPStrategy(bt.Strategy):
    params = (
        ("stop_loss", 0.02),  # 2% stop loss
        # ("take_profit", 0.04),  # 4% take profit
        ("risk", 0.01),  # 1% risk
        ("pivot_window", 5),  # 5 bars for pivot high/low
        ("rrr", 2),  # Risk-Reward Ratio
        ("trailpercent", 0.05),     # Percent Price for Trailing stop
        ("sl_pips", 50),
        ("pip_value", 0.01)     # Pip value for Gold (XAUUSD)
    )
    def __init__(self):
        # initialize the VWAP indicator on data feed
        self.vwap = VWAPRollingIndicator(self.data)
        self.crossover = bt.indicators.CrossOver(self.data.close, self.vwap)
        self.order = None
        self.prev_pivot_high = self.data.low[0]
        self.prev_pivot_low = self.data.high[0]
        
    def notify_order(self, order):
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'BUY EXECUTED, {order.executed.price:.2f}')
            elif order.issell():
                self.log(f'SELL EXECUTED, {order.executed.price:.2f}')
        self.order = None
    
    def log(self, txt):
        dt = self.data.datetime.date(0)
        print(f'{dt.isoformat()} {txt}')
    
    def _calculate_size(self, price, sl_price):
        # Calculate the size of the position based on the risk percentage and stop loss
        size = (self.broker.getvalue() * self.params.risk) / abs(price - sl_price)
        return size
    
    def _update_pivots(self):
        if np.max(self.data.high.get(size=self.params.pivot_window * 2 + 1)) == self.data.high[self.params.pivot_window]:
            self.prev_pivot_high = self.data.high[self.params.pivot_window]   
        if np.min(self.data.low.get(size=self.params.pivot_window * 2 + 1)) == self.data.low[self.params.pivot_window]:
            self.prev_pivot_low = self.data.low[self.params.pivot_window]      

    def next(self):
        # if not in a market position, check for crossover from below
        if not self.position:
            if self.crossover > 0 and self.data.close[1] > self.data.open[1]:
                price = self.data.close[0]
                # sl_price = self.data.low[1]
                # sl_price = price * (1 - self.params.stop_loss)
                sl_price = price - self.params.sl_pips * self.params.pip_value
                tp_price = price + np.abs(sl_price - price) * self.params.rrr
                if tp_price < price:
                    self.log(f'Take profit price {tp_price:.2f} is less than entry price {price:.2f}, not placing order.')
                    return
                if sl_price > price:
                    self.log(f'Stop loss price {sl_price:.2f} is greater than entry price {price:.2f}, not placing order.')
                    return

                # size = self._calculate_size(price, sl_price)
                self.order = self.buy_bracket(
                    exectype=bt.Order.Market, 
                    # size=size,
                    price=price,
                    stopprice=sl_price,
                    limitprice=tp_price,
                    stopargs=dict(exectype=bt.Order.Stop),
                    limitargs=dict(exectype=bt.Order.Limit),
                    # trailpercent=self.params.trailpercent
                )
                self.log(f"Bracket order placed: Entry {price:.2f}, SL {sl_price:.2f}, TP {tp_price:.2f}")
 
            # if in a position, check for crossover from above for exit
            elif self.crossover < 0 and self.data.close[1] < self.data.open[1]:
                price = self.data.close[0]
                # sl_price = self.data.high[1]
                # sl_price = price * (1 + self.params.stop_loss)
                sl_price = price + self.params.sl_pips * self.params.pip_value
                tp_price = price - np.abs(sl_price - price) * self.params.rrr
                if tp_price > price:
                    self.log(f'Take profit price {tp_price:.2f} is greater than entry price {price:.2f}, not placing order.')
                    return
                if sl_price < price:
                    self.log(f'Stop loss price {sl_price:.2f} is less than entry price {price:.2f}, not placing order.')
                    return
                # size = self._calculate_size(price, sl_price)
                self.order = self.sell_bracket(
                    exectype=bt.Order.Market, 
                    # size=size,
                    price=price,
                    stopprice=sl_price,
                    limitprice=tp_price,
                    stopargs=dict(exectype=bt.Order.Stop),
                    limitargs=dict(exectype=bt.Order.Limit),
                    # trailpercent=self.params.trailpercent
                )
                self.log(f"Bracket order placed: Entry {price:.2f}, SL {sl_price:.2f}, TP {tp_price:.2f}")
        else:
            pass

# %% [markdown]
# ## Download Data from YF

# %%
# Download SPX500 data from Yahoo Finance
yf_params = {'start': '2018-01-01', 'end': '2024-01-01', 'interval': '1d', 'multi_level_index': False}
# data = yf.download(tickers="^GSPC", **yf_params)
# data = yf.download(tickers="DJIA", **yf_params)
# data = yf.download(tickers="^VIX", **yf_params)
# data = yf.download(tickers="^RUT", **yf_params)
# data = yf.download(tickers="^IXIC", **yf_params)
# data = yf.download(tickers="GOOG", **yf_params)
# data = yf.download(tickers="AAPL", **yf_params)
# data = yf.download(tickers="MSFT", **yf_params)
# data = yf.download(tickers="AMZN", **yf_params)
# data = yf.download(tickers="TSLA", **yf_params)
# data = yf.download(tickers="META", **yf_params)
data = yf.download(tickers="NFLX", **yf_params)
# data = yf.download(tickers="NVDA", **yf_params)
# data = yf.download(tickers="AMD", **yf_params)
data.reset_index(inplace=True)
data['Date'] = pd.to_datetime(data['Date'])
# data.set_index('Date', inplace=True)

# data
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Source data locally

# %%
data_local = pd.read_csv("./data/xau_usd_5m.csv", index_col=None)
data_local['datetime'] = pd.to_datetime(data_local['datetime'])
print(data_local.head())

data_feed_local = bt.feeds.PandasData(dataname=data_local, name="xau",
                                      datetime=0, openinterest=-1,
                                      open=1,
                                      high=2,
                                      low=3,
                                      close=4,
                                      volume=5)
# Out:
#              datetime         open         high          low        close  \
# 0 2020-02-02 23:00:00  1591.197998  1591.197998  1587.751953  1588.687012
# 1 2020-02-02 23:05:00  1588.734009  1590.536987  1588.064941  1590.447998
# 2 2020-02-02 23:10:00  1590.500000  1592.167969  1588.849976  1589.462036
# 3 2020-02-02 23:15:00  1589.421997  1590.144043  1588.848999  1589.894043
# 4 2020-02-02 23:20:00  1589.943970  1590.021973  1588.385010  1588.942017
#
#    volume
# 0     547
# 1     372
# 2     606
# 3     242
# 4     246

# %%
cerebro = bt.Cerebro()
cerebro.addstrategy(VWAPStrategy, 
                    # stop_loss=0.10, 
                    # trailpercent=0.05, 
                    # pivot_window=5, 
                    sl_pips=300,
                    pip_value=0.01,
                    rrr=2.0,
                    risk=0.02
                    )
cerebro.broker.setcash(100_000.0)
cerebro.broker.setcommission(commission=0.001)
data_feed = bt.feeds.pandafeed.PandasData(
    dataname=data,
    datetime=0,
    openinterest=-1,
    open=1,
    high=2,
    low=3,
    close=4,
    volume=5,
)
cerebro.adddata(data_feed_local)

# %%
cerebro.addsizer(bt.sizers.PercentSizer, percents=0.02)
cerebro.addanalyzer(bt.analyzers.SharpeRatio, riskfreerate=0.01)
cerebro.addanalyzer(bt.analyzers.DrawDown)
cerebro.addanalyzer(bt.analyzers.TradeAnalyzer)
cerebro.addanalyzer(bt.analyzers.Returns)

results = cerebro.run()
# Out:
# 2020-02-03 Bracket order placed: Entry 1589.06, SL 1594.06, TP 1579.06
# 2020-02-03 SELL EXECUTED, 1589.10
# 2020-02-03 BUY EXECUTED, 1579.06
# 2020-02-03 Bracket order placed: Entry 1577.94, SL 1572.94, TP 1587.94
# 2020-02-03 BUY EXECUTED, 1577.90
# 2020-02-03 SELL EXECUTED, 1572.94
# 2020-02-03 Bracket order placed: Entry 1574.99, SL 1569.99, TP 1584.99
# 2020-02-03 BUY EXECUTED, 1575.03
# 2020-02-04 SELL EXECUTED, 1569.99
# 2020-02-04 Bracket order placed: Entry 1567.46, SL 1562.46, TP 1577.46
# 2020-02-04 BUY EXECUTED, 1567.42
# 2020-02-04 SELL EXECUTED, 1562.46
# 2020-02-04 Bracket order placed: Entry 1555.47, SL 1550.47, TP 1565.47
# 2020-02-04 BUY EXECUTED, 1555.51
# 2020-02-04 SELL EXECUTED, 1550.47
# 2020-02-04 Bracket order placed: Entry 1551.77, SL 1546.77, TP 1561.77
# 2020-02-04 BUY EXECUTED, 1551.73
# 2020-02-05 SELL EXECUTED, 1561.77
# 2020-02-05 Bracket order placed: Entry 1561.12, SL 1556.12, TP 1571.12
# 2020-02-05 BUY EXECUTED, 1561.16
# 2020-02-05 SELL EXECUTED, 1556.12
# 2020-02-05 Bracket order placed: Entry 1551.96, SL 1546.96, TP 1561.96
# 2020-02-05 BUY EXECUTED, 1552.01
# 2020-02-06 SELL EXECUTED, 1561.96
# 2020-02-06 Bracket order placed: Entry 1565.08, SL 1570.08, TP 1555.08
# 2020-02-06 SELL EXECUTED, 1565.04
# 2020-02-07 BUY EXECUTED, 1570.08
# 2020-02-07 Bracket order placed: Entry 1571.01, SL 1576.01, TP 1561.01
# 2020-02-07 SELL EXECUTED, 1571.05
# 2020-02-09 BUY EXECUTED, 1576.01
# 2020-02-10 Bracket order placed: Entry 1573.88, SL 1578.88, TP 1563.88
# 2020-02-10 SELL EXECUTED, 1573.83
# 2020-02-11 BUY EXECUTED, 1563.88
# 2020-02-11 Bracket order placed: Entry 1565.83, SL 1560.83, TP 1575.83
# 2020-02-11 BUY EXECUTED, 1565.87
# 2020-02-13 SELL EXECUTED, 1575.83
# 2020-02-13 Bracket order placed: Entry 1574.75, SL 1569.75, TP 1584.75
# 2020-02-13 BUY EXECUTED, 1574.80
# 2020-02-14 SELL EXECUTED, 1584.75
# 2020-02-16 Bracket order placed: Entry 1581.53, SL 1586.53, TP 1571.53
# 2020-02-16 SELL EXECUTED, 1581.49
# 2020-02-18 BUY EXECUTED, 1586.53
# 2020-02-18 Bracket order placed: Entry 1586.12, SL 1591.12, TP 1576.12
# 2020-02-18 SELL EXECUTED, 1586.08
# 2020-02-18 BUY EXECUTED, 1591.12
# 2020-02-18 Bracket order placed: Entry 1591.16, SL 1586.16, TP 1601.16
# 2020-02-18 BUY EXECUTED, 1591.12
# 2020-02-18 SELL EXECUTED, 1601.16
# 2020-02-18 Bracket order placed: Entry 1602.09, SL 1607.09, TP 1592.09
# 2020-02-18 SELL EXECUTED, 1602.14
# 2020-02-19 BUY EXECUTED, 1607.09
# 2020-02-19 Bracket order placed: Entry 1607.95, SL 1612.95, TP 1597.95
# 2020-02-19 SELL EXECUTED, 1607.91
# 2020-02-19 BUY EXECUTED, 1612.95
# 2020-02-19 Bracket order placed: Entry 1611.45, SL 1616.45, TP 1601.45
# 2020-02-19 SELL EXECUTED, 1611.41
# 2020-02-20 BUY EXECUTED, 1616.45
# 2020-02-20 Bracket order placed: Entry 1617.25, SL 1622.25, TP 1607.25
# 2020-02-20 SELL EXECUTED, 1617.30
# 2020-02-20 BUY EXECUTED, 1622.25
# 2020-02-20 Bracket order placed: Entry 1617.91, SL 1622.91, TP 1607.91
# 2020-02-20 SELL EXECUTED, 1617.87
# 2020-02-20 BUY EXECUTED, 1622.91
# 2020-02-20 Bracket order placed: Entry 1622.10, SL 1617.10, TP 1632.10
# 2020-02-20 BUY EXECUTED, 1622.06
# 2020-02-20 SELL EXECUTED, 1617.10
# 2020-02-20 Bracket order placed: Entry 1618.35, SL 1613.35, TP 1628.35
# 2020-02-20 BUY EXECUTED, 1618.39
# 2020-02-21 SELL EXECUTED, 1628.35
# 2020-02-21 Bracket order placed: Entry 1633.45, SL 1628.45, TP 1643.45
# 2020-02-21 BUY EXECUTED, 1633.41
# 2020-02-21 SELL EXECUTED, 1643.45
# 2020-02-21 Bracket order placed: Entry 1641.85, SL 1636.85, TP 1651.85
# 2020-02-21 BUY EXECUTED, 1641.89
# 2020-02-23 SELL EXECUTED, 1651.85
# 2020-02-23 Bracket order placed: Entry 1659.78, SL 1654.78, TP 1669.78
# 2020-02-23 BUY EXECUTED, 1659.82
# 2020-02-23 SELL EXECUTED, 1669.78
# 2020-02-23 Bracket order placed: Entry 1664.22, SL 1669.22, TP 1654.22
# 2020-02-23 SELL EXECUTED, 1664.26
# 2020-02-24 BUY EXECUTED, 1669.22
# 2020-02-24 Bracket order placed: Entry 1667.56, SL 1672.56, TP 1657.56
# 2020-02-24 SELL EXECUTED, 1667.51
# 2020-02-24 BUY EXECUTED, 1672.56
# 2020-02-24 Bracket order placed: Entry 1684.80, SL 1679.80, TP 1694.80
# 2020-02-24 BUY EXECUTED, 1684.84
# 2020-02-24 SELL EXECUTED, 1679.80
# 2020-02-24 Bracket order placed: Entry 1681.84, SL 1676.84, TP 1691.84
# 2020-02-24 BUY EXECUTED, 1681.80
# 2020-02-24 SELL EXECUTED, 1676.84
# 2020-02-24 Bracket order placed: Entry 1677.78, SL 1682.78, TP 1667.78
# 2020-02-24 SELL EXECUTED, 1677.82
# 2020-02-24 BUY EXECUTED, 1682.78
# 2020-02-24 Bracket order placed: Entry 1677.53, SL 1682.53, TP 1667.53
# 2020-02-24 SELL EXECUTED, 1677.48
# 2020-02-24 BUY EXECUTED, 1667.53
# 2020-02-24 Bracket order placed: Entry 1657.80, SL 1662.80, TP 1647.80
# 2020-02-24 SELL EXECUTED, 1657.76
# 2020-02-24 BUY EXECUTED, 1663.11
# 2020-02-24 Bracket order placed: Entry 1656.57, SL 1661.57, TP 1646.57
# 2020-02-24 SELL EXECUTED, 1656.53
# 2020-02-25 BUY EXECUTED, 1646.57
# 2020-02-25 Bracket order placed: Entry 1647.87, SL 1652.87, TP 1637.87
# 2020-02-25 SELL EXECUTED, 1647.83
# 2020-02-25 BUY EXECUTED, 1652.87
# 2020-02-25 Bracket order placed: Entry 1656.87, SL 1651.87, TP 1666.87
# 2020-02-25 BUY EXECUTED, 1656.91
# 2020-02-25 SELL EXECUTED, 1651.87
# 2020-02-25 Bracket order placed: Entry 1638.21, SL 1633.21, TP 1648.21
# 2020-02-25 BUY EXECUTED, 1638.25
# 2020-02-25 SELL EXECUTED, 1648.21
# 2020-02-25 Bracket order placed: Entry 1650.27, SL 1655.27, TP 1640.27
# 2020-02-25 SELL EXECUTED, 1650.23
# 2020-02-25 BUY EXECUTED, 1655.27
# 2020-02-25 Bracket order placed: Entry 1653.18, SL 1658.18, TP 1643.18
# 2020-02-25 SELL EXECUTED, 1653.14
# 2020-02-25 BUY EXECUTED, 1643.18
# 2020-02-25 Bracket order placed: Entry 1647.16, SL 1642.16, TP 1657.16
# 2020-02-25 BUY EXECUTED, 1647.21
# 2020-02-25 SELL EXECUTED, 1657.16
# 2020-02-25 Bracket order placed: Entry 1654.70, SL 1649.70, TP 1664.70
# 2020-02-25 BUY EXECUTED, 1654.65
# 2020-02-25 SELL EXECUTED, 1649.70
# 2020-02-25 Bracket order placed: Entry 1645.51, SL 1640.51, TP 1655.51
# 2020-02-25 BUY EXECUTED, 1645.47
# 2020-02-25 SELL EXECUTED, 1640.51
# 2020-02-25 Bracket order placed: Entry 1634.90, SL 1629.90, TP 1644.90
# 2020-02-25 BUY EXECUTED, 1634.94
# 2020-02-26 SELL EXECUTED, 1644.90
# 2020-02-26 Bracket order placed: Entry 1643.77, SL 1648.77, TP 1633.77
# 2020-02-26 SELL EXECUTED, 1643.81
# 2020-02-26 BUY EXECUTED, 1648.77
# 2020-02-26 Bracket order placed: Entry 1647.96, SL 1642.96, TP 1657.96
# 2020-02-26 BUY EXECUTED, 1647.92
# 2020-02-26 SELL EXECUTED, 1642.96
# 2020-02-26 Bracket order placed: Entry 1645.51, SL 1640.51, TP 1655.51
# 2020-02-26 BUY EXECUTED, 1645.47
# 2020-02-26 SELL EXECUTED, 1640.51
# 2020-02-26 Bracket order placed: Entry 1633.63, SL 1628.63, TP 1643.63
# 2020-02-26 BUY EXECUTED, 1633.59
# 2020-02-26 SELL EXECUTED, 1643.63
# 2020-02-26 Bracket order placed: Entry 1641.41, SL 1646.41, TP 1631.41
# 2020-02-26 SELL EXECUTED, 1641.36
# 2020-02-26 BUY EXECUTED, 1646.41
# 2020-02-26 Bracket order placed: Entry 1646.69, SL 1651.69, TP 1636.69
# 2020-02-26 SELL EXECUTED, 1646.65
# 2020-02-26 BUY EXECUTED, 1636.69
# 2020-02-26 Bracket order placed: Entry 1640.63, SL 1635.63, TP 1650.63
# 2020-02-26 BUY EXECUTED, 1640.68
# 2020-02-27 SELL EXECUTED, 1650.63
# 2020-02-27 Bracket order placed: Entry 1649.71, SL 1654.71, TP 1639.71
# 2020-02-27 SELL EXECUTED, 1649.67
# 2020-02-27 BUY EXECUTED, 1654.71
# 2020-02-27 Bracket order placed: Entry 1654.20, SL 1649.20, TP 1664.20
# 2020-02-27 BUY EXECUTED, 1654.24
# 2020-02-27 SELL EXECUTED, 1649.20
# 2020-02-27 Bracket order placed: Entry 1650.07, SL 1655.07, TP 1640.07
# 2020-02-27 SELL EXECUTED, 1650.11
# 2020-02-27 BUY EXECUTED, 1640.07
# 2020-02-27 Bracket order placed: Entry 1643.40, SL 1638.40, TP 1653.40
# 2020-02-27 BUY EXECUTED, 1643.44
# 2020-02-27 SELL EXECUTED, 1638.40
# 2020-02-27 Bracket order placed: Entry 1639.27, SL 1634.27, TP 1649.27
# 2020-02-27 BUY EXECUTED, 1639.23
# 2020-02-27 SELL EXECUTED, 1649.27
# 2020-02-27 Bracket order placed: Entry 1645.66, SL 1650.66, TP 1635.66
# 2020-02-27 SELL EXECUTED, 1645.61
# 2020-02-28 BUY EXECUTED, 1635.66
# 2020-02-28 Bracket order placed: Entry 1638.94, SL 1633.94, TP 1648.94
# 2020-02-28 BUY EXECUTED, 1638.90
# 2020-02-28 SELL EXECUTED, 1633.94
# 2020-02-28 Bracket order placed: Entry 1630.22, SL 1635.22, TP 1620.22
# 2020-02-28 SELL EXECUTED, 1630.27
# 2020-02-28 BUY EXECUTED, 1635.22
# 2020-02-28 Bracket order placed: Entry 1631.43, SL 1636.43, TP 1621.43
# 2020-02-28 SELL EXECUTED, 1631.47
# 2020-02-28 BUY EXECUTED, 1636.43
# 2020-02-28 Bracket order placed: Entry 1628.21, SL 1623.21, TP 1638.21
# 2020-02-28 BUY EXECUTED, 1628.16
# 2020-02-28 SELL EXECUTED, 1623.21
# 2020-02-28 Bracket order placed: Entry 1621.83, SL 1626.83, TP 1611.83
# 2020-02-28 SELL EXECUTED, 1621.87
# 2020-02-28 BUY EXECUTED, 1626.83
# 2020-02-28 Bracket order placed: Entry 1626.87, SL 1621.87, TP 1636.87
# 2020-02-28 BUY EXECUTED, 1626.91
# 2020-02-28 SELL EXECUTED, 1621.87
# 2020-03-09 SELL EXECUTED, 1677.36
# 2020-03-09 Bracket order placed: Entry 1679.17, SL 1684.17, TP 1669.17
# 2020-03-09 SELL EXECUTED, 1679.23
# 2020-03-09 BUY EXECUTED, 1669.17
# 2020-03-09 Bracket order placed: Entry 1667.99, SL 1662.99, TP 1677.99
# 2020-03-09 BUY EXECUTED, 1667.95
# 2020-03-09 SELL EXECUTED, 1677.99
# 2020-03-09 Bracket order placed: Entry 1678.21, SL 1683.21, TP 1668.21
# 2020-03-09 SELL EXECUTED, 1678.17
# 2020-03-09 BUY EXECUTED, 1683.21
# 2020-03-09 Bracket order placed: Entry 1677.50, SL 1682.50, TP 1667.50
# 2020-03-09 SELL EXECUTED, 1677.54
# 2020-03-09 BUY EXECUTED, 1667.50
# 2020-03-09 Bracket order placed: Entry 1670.85, SL 1675.85, TP 1660.85
# 2020-03-09 SELL EXECUTED, 1670.80
# 2020-03-09 BUY EXECUTED, 1675.85
# 2020-03-09 Bracket order placed: Entry 1676.03, SL 1671.03, TP 1686.03
# 2020-03-09 BUY EXECUTED, 1675.98
# 2020-03-09 SELL EXECUTED, 1671.03
# 2020-03-10 Bracket order placed: Entry 1667.63, SL 1662.63, TP 1677.63
# 2020-03-10 BUY EXECUTED, 1667.57
# 2020-03-10 SELL EXECUTED, 1662.63
# 2020-03-10 Bracket order placed: Entry 1667.97, SL 1672.97, TP 1657.97
# 2020-03-10 SELL EXECUTED, 1668.01
# 2020-03-10 BUY EXECUTED, 1657.97
# 2020-03-10 Bracket order placed: Entry 1657.61, SL 1652.61, TP 1667.61
# 2020-03-10 BUY EXECUTED, 1657.54
# 2020-03-10 SELL EXECUTED, 1667.61
# 2020-03-10 Bracket order placed: Entry 1664.26, SL 1669.26, TP 1654.26
# 2020-03-10 SELL EXECUTED, 1664.31
# 2020-03-10 BUY EXECUTED, 1654.26
# 2020-03-10 Bracket order placed: Entry 1656.54, SL 1651.54, TP 1666.54
# 2020-03-10 BUY EXECUTED, 1656.62
# 2020-03-10 SELL EXECUTED, 1651.54
# 2020-03-10 Bracket order placed: Entry 1655.51, SL 1650.51, TP 1665.51
# 2020-03-10 BUY EXECUTED, 1655.46
# 2020-03-10 SELL EXECUTED, 1650.51
# 2020-03-10 Bracket order placed: Entry 1649.11, SL 1644.11, TP 1659.11
# 2020-03-10 BUY EXECUTED, 1649.07
# 2020-03-11 SELL EXECUTED, 1659.11
# 2020-03-11 Bracket order placed: Entry 1657.53, SL 1662.53, TP 1647.53
# 2020-03-11 SELL EXECUTED, 1657.57
# 2020-03-11 BUY EXECUTED, 1662.53
# 2020-03-11 Bracket order placed: Entry 1662.31, SL 1667.31, TP 1652.31
# 2020-03-11 SELL EXECUTED, 1662.26
# 2020-03-11 BUY EXECUTED, 1667.31
# 2020-03-11 Bracket order placed: Entry 1666.96, SL 1661.96, TP 1676.96
# 2020-03-11 BUY EXECUTED, 1666.92
# 2020-03-11 SELL EXECUTED, 1661.96
# 2020-03-11 Bracket order placed: Entry 1662.38, SL 1667.38, TP 1652.38
# 2020-03-11 SELL EXECUTED, 1662.43
# 2020-03-19 BUY EXECUTED, 1468.80
# 2020-03-20 SELL EXECUTED, 1478.74
# 2020-03-20 Bracket order placed: Entry 1481.56, SL 1486.56, TP 1471.56
# 2020-03-20 SELL EXECUTED, 1481.52
# 2020-03-20 BUY EXECUTED, 1486.56
# 2020-03-20 Bracket order placed: Entry 1508.59, SL 1513.59, TP 1498.59
# 2020-03-20 SELL EXECUTED, 1508.67
# 2020-03-20 BUY EXECUTED, 1513.59
# 2020-03-20 Bracket order placed: Entry 1501.30, SL 1506.30, TP 1491.30
# 2020-03-20 SELL EXECUTED, 1501.26
# 2020-03-20 BUY EXECUTED, 1491.30
# 2020-03-20 Bracket order placed: Entry 1495.86, SL 1500.86, TP 1485.86
# 2020-03-20 SELL EXECUTED, 1495.82
# 2020-03-20 BUY EXECUTED, 1485.86
# 2020-03-20 Bracket order placed: Entry 1484.67, SL 1479.67, TP 1494.67
# 2020-03-20 BUY EXECUTED, 1484.71
# 2020-03-20 SELL EXECUTED, 1479.67
# 2020-03-20 Bracket order placed: Entry 1481.73, SL 1486.73, TP 1471.73
# 2020-03-20 SELL EXECUTED, 1481.68
# 2020-03-20 BUY EXECUTED, 1486.73
# 2020-03-20 Bracket order placed: Entry 1487.94, SL 1482.94, TP 1497.94
# 2020-03-20 BUY EXECUTED, 1487.99
# 2020-03-20 SELL EXECUTED, 1497.94
# 2020-03-22 Bracket order placed: Entry 1498.04, SL 1503.04, TP 1488.04
# 2020-03-22 SELL EXECUTED, 1497.97
# 2020-03-22 BUY EXECUTED, 1488.04
# 2020-03-22 Bracket order placed: Entry 1493.93, SL 1488.93, TP 1503.93
# 2020-03-22 BUY EXECUTED, 1493.88
# 2020-03-22 SELL EXECUTED, 1488.93
# 2020-03-23 Bracket order placed: Entry 1495.05, SL 1500.05, TP 1485.05
# 2020-03-23 SELL EXECUTED, 1495.10
# 2020-03-23 BUY EXECUTED, 1500.05
# 2020-03-23 Bracket order placed: Entry 1515.63, SL 1510.63, TP 1525.63
# 2020-03-23 BUY EXECUTED, 1515.67
# 2020-03-23 SELL EXECUTED, 1525.63
# 2020-03-23 Bracket order placed: Entry 1554.94, SL 1559.94, TP 1544.94
# 2020-03-23 SELL EXECUTED, 1554.82
# 2020-03-23 BUY EXECUTED, 1559.94
# 2020-03-23 Bracket order placed: Entry 1563.08, SL 1558.08, TP 1573.08
# 2020-03-23 BUY EXECUTED, 1563.17
# 2020-03-24 SELL EXECUTED, 1573.08
# 2020-03-24 Bracket order placed: Entry 1575.70, SL 1580.70, TP 1565.70
# 2020-03-24 SELL EXECUTED, 1575.61
# 2020-03-24 BUY EXECUTED, 1580.70
# 2020-03-24 Bracket order placed: Entry 1576.34, SL 1581.34, TP 1566.34
# 2020-03-24 SELL EXECUTED, 1576.25
# 2020-03-24 BUY EXECUTED, 1566.34
# 2020-03-24 Bracket order placed: Entry 1567.29, SL 1562.29, TP 1577.29
# 2020-03-24 BUY EXECUTED, 1567.42
# 2020-03-24 SELL EXECUTED, 1577.29
# 2020-03-24 Bracket order placed: Entry 1581.34, SL 1586.34, TP 1571.34
# 2020-03-24 SELL EXECUTED, 1581.44
# 2020-03-24 BUY EXECUTED, 1586.34
# 2020-03-24 Bracket order placed: Entry 1586.77, SL 1581.77, TP 1596.77
# 2020-03-24 BUY EXECUTED, 1586.12
# 2020-03-24 SELL EXECUTED, 1596.77
# 2020-03-24 Bracket order placed: Entry 1600.12, SL 1595.12, TP 1610.12
# 2020-03-24 BUY EXECUTED, 1599.41
# 2020-03-24 SELL EXECUTED, 1610.12
# 2020-03-24 Bracket order placed: Entry 1602.71, SL 1597.71, TP 1612.71
# 2020-03-24 BUY EXECUTED, 1601.41
# 2020-03-24 SELL EXECUTED, 1597.71
# 2020-03-24 Bracket order placed: Entry 1628.06, SL 1633.06, TP 1618.06
# 2020-03-24 SELL EXECUTED, 1627.15
# 2020-03-24 BUY EXECUTED, 1633.06
# 2020-03-24 Bracket order placed: Entry 1629.77, SL 1624.77, TP 1639.77
# 2020-03-24 BUY EXECUTED, 1629.61
# 2020-03-24 SELL EXECUTED, 1624.77
# 2020-03-24 Bracket order placed: Entry 1627.18, SL 1632.18, TP 1617.18
# 2020-03-24 SELL EXECUTED, 1627.26
# 2020-03-24 BUY EXECUTED, 1632.18
# 2020-03-24 Bracket order placed: Entry 1634.24, SL 1629.24, TP 1644.24
# 2020-03-24 BUY EXECUTED, 1633.63
# 2020-03-25 SELL EXECUTED, 1629.24
# 2020-03-25 Bracket order placed: Entry 1618.75, SL 1623.75, TP 1608.75
# 2020-03-25 SELL EXECUTED, 1618.85
# 2020-03-25 BUY EXECUTED, 1608.75
# 2020-03-25 Bracket order placed: Entry 1615.88, SL 1610.88, TP 1625.88
# 2020-03-25 BUY EXECUTED, 1615.80
# 2020-03-25 SELL EXECUTED, 1610.88
# 2020-03-25 Bracket order placed: Entry 1610.83, SL 1605.83, TP 1620.83
# 2020-03-25 BUY EXECUTED, 1611.00
# 2020-03-25 SELL EXECUTED, 1605.83
# 2020-03-25 Bracket order placed: Entry 1609.41, SL 1604.41, TP 1619.41
# 2020-03-25 BUY EXECUTED, 1609.62
# 2020-03-25 SELL EXECUTED, 1604.41
# 2020-03-25 Bracket order placed: Entry 1605.64, SL 1600.64, TP 1615.64
# 2020-03-25 BUY EXECUTED, 1605.80
# 2020-03-25 SELL EXECUTED, 1600.64
# 2020-03-25 Bracket order placed: Entry 1620.10, SL 1625.10, TP 1610.10
# 2020-03-25 SELL EXECUTED, 1619.97
# 2020-03-25 BUY EXECUTED, 1610.10
# 2020-03-25 Bracket order placed: Entry 1611.87, SL 1616.87, TP 1601.87
# 2020-03-25 SELL EXECUTED, 1611.73
# 2020-03-25 BUY EXECUTED, 1616.87
# 2020-03-25 Bracket order placed: Entry 1610.30, SL 1615.30, TP 1600.30
# 2020-03-25 SELL EXECUTED, 1609.85
# 2020-03-25 BUY EXECUTED, 1615.30
# 2020-03-25 Bracket order placed: Entry 1613.26, SL 1618.26, TP 1603.26
# 2020-03-25 SELL EXECUTED, 1613.17
# 2020-03-26 BUY EXECUTED, 1603.26
# 2020-03-26 Bracket order placed: Entry 1606.64, SL 1611.64, TP 1596.64
# 2020-03-26 SELL EXECUTED, 1606.74
# 2020-03-26 BUY EXECUTED, 1611.64
# 2020-03-26 Bracket order placed: Entry 1631.20, SL 1626.20, TP 1641.20
# 2020-03-26 BUY EXECUTED, 1631.35
# 2020-03-26 SELL EXECUTED, 1626.20
# 2020-03-26 Bracket order placed: Entry 1629.13, SL 1634.13, TP 1619.13
# 2020-03-26 SELL EXECUTED, 1629.32
# 2020-03-26 BUY EXECUTED, 1634.13
# 2020-03-26 Bracket order placed: Entry 1638.48, SL 1643.48, TP 1628.48
# 2020-03-26 SELL EXECUTED, 1638.59
# 2020-03-26 BUY EXECUTED, 1628.48
# 2020-03-26 Bracket order placed: Entry 1629.23, SL 1624.23, TP 1639.23
# 2020-03-26 BUY EXECUTED, 1629.14
# 2020-03-26 SELL EXECUTED, 1624.23
# 2020-03-27 Bracket order placed: Entry 1627.49, SL 1622.49, TP 1637.49
# 2020-03-27 BUY EXECUTED, 1627.40
# 2020-03-27 SELL EXECUTED, 1622.49
# 2020-03-27 Bracket order placed: Entry 1623.85, SL 1618.85, TP 1633.85
# 2020-03-27 BUY EXECUTED, 1624.04
# 2020-03-27 SELL EXECUTED, 1618.85
# 2020-03-27 Bracket order placed: Entry 1620.55, SL 1625.55, TP 1610.55
# 2020-03-27 SELL EXECUTED, 1620.45
# 2020-03-27 BUY EXECUTED, 1625.55
# 2020-03-27 Bracket order placed: Entry 1622.77, SL 1627.77, TP 1612.77
# 2020-03-27 SELL EXECUTED, 1622.86
# 2020-03-27 BUY EXECUTED, 1627.77
# 2020-03-27 Bracket order placed: Entry 1620.01, SL 1625.01, TP 1610.01
# 2020-03-27 SELL EXECUTED, 1620.41
# 2020-03-27 BUY EXECUTED, 1625.01
# 2020-03-27 Bracket order placed: Entry 1623.30, SL 1618.30, TP 1633.30
# 2020-03-27 BUY EXECUTED, 1623.19
# 2020-03-30 SELL EXECUTED, 1618.30
# 2020-03-30 Bracket order placed: Entry 1620.46, SL 1625.46, TP 1610.46
# 2020-03-30 SELL EXECUTED, 1620.20
# 2020-03-30 BUY EXECUTED, 1625.46
# 2020-03-30 Bracket order placed: Entry 1623.87, SL 1628.87, TP 1613.87
# 2020-03-30 SELL EXECUTED, 1623.79
# 2020-03-30 BUY EXECUTED, 1613.87
# 2020-03-30 Bracket order placed: Entry 1617.99, SL 1612.99, TP 1627.99
# 2020-03-30 BUY EXECUTED, 1618.14
# 2020-03-30 SELL EXECUTED, 1612.99
# 2020-03-30 Bracket order placed: Entry 1622.19, SL 1627.19, TP 1612.19
# 2020-03-30 SELL EXECUTED, 1622.06
# 2020-03-31 BUY EXECUTED, 1612.19
# 2020-03-31 Bracket order placed: Entry 1614.92, SL 1619.92, TP 1604.92
# 2020-03-31 SELL EXECUTED, 1614.68
# 2020-03-31 BUY EXECUTED, 1604.92
# 2020-03-31 Bracket order placed: Entry 1606.41, SL 1611.41, TP 1596.41
# 2020-03-31 SELL EXECUTED, 1606.31
# 2020-03-31 BUY EXECUTED, 1596.41
# 2020-03-31 Bracket order placed: Entry 1600.57, SL 1605.57, TP 1590.57
# 2020-03-31 SELL EXECUTED, 1600.49
# 2020-03-31 BUY EXECUTED, 1605.57
# 2020-03-31 Bracket order placed: Entry 1604.91, SL 1609.91, TP 1594.91
# 2020-03-31 SELL EXECUTED, 1605.00
# 2020-03-31 BUY EXECUTED, 1609.91
# 2020-03-31 Bracket order placed: Entry 1610.36, SL 1605.36, TP 1620.36
# 2020-03-31 BUY EXECUTED, 1610.28
# 2020-03-31 SELL EXECUTED, 1605.36
# 2020-03-31 Bracket order placed: Entry 1610.92, SL 1605.92, TP 1620.92
# 2020-03-31 BUY EXECUTED, 1611.02
# 2020-03-31 SELL EXECUTED, 1605.92
# 2020-03-31 Bracket order placed: Entry 1590.35, SL 1585.35, TP 1600.35
# 2020-03-31 BUY EXECUTED, 1590.44
# 2020-03-31 SELL EXECUTED, 1585.35
# 2020-03-31 Bracket order placed: Entry 1576.84, SL 1571.84, TP 1586.84
# 2020-03-31 BUY EXECUTED, 1577.14
# 2020-04-01 SELL EXECUTED, 1586.84
# 2020-04-01 Bracket order placed: Entry 1586.98, SL 1581.98, TP 1596.98
# 2020-04-01 BUY EXECUTED, 1587.06
# 2020-04-01 SELL EXECUTED, 1596.98
# 2020-04-01 Bracket order placed: Entry 1595.48, SL 1600.48, TP 1585.48
# 2020-04-01 SELL EXECUTED, 1595.40
# 2020-04-01 BUY EXECUTED, 1585.48
# 2020-04-01 Bracket order placed: Entry 1584.93, SL 1579.93, TP 1594.93
# 2020-04-01 BUY EXECUTED, 1584.84
# 2020-04-01 SELL EXECUTED, 1579.93
# 2020-04-01 Bracket order placed: Entry 1578.82, SL 1573.82, TP 1588.82
# 2020-04-01 BUY EXECUTED, 1578.73
# 2020-04-01 SELL EXECUTED, 1588.82
# 2020-04-01 Bracket order placed: Entry 1586.94, SL 1591.94, TP 1576.94
# 2020-04-01 SELL EXECUTED, 1587.02
# 2020-04-01 BUY EXECUTED, 1591.94
# 2020-04-01 Bracket order placed: Entry 1588.57, SL 1593.57, TP 1578.57
# 2020-04-01 SELL EXECUTED, 1588.44
# 2020-04-01 BUY EXECUTED, 1578.57
# 2020-04-01 Bracket order placed: Entry 1582.65, SL 1577.65, TP 1592.65
# 2020-04-01 BUY EXECUTED, 1582.46
# 2020-04-01 SELL EXECUTED, 1592.65
# 2020-04-01 Bracket order placed: Entry 1588.47, SL 1593.47, TP 1578.47
# 2020-04-01 SELL EXECUTED, 1588.56
# 2020-04-01 BUY EXECUTED, 1593.47
# 2020-04-01 Bracket order placed: Entry 1592.48, SL 1587.48, TP 1602.48
# 2020-04-01 BUY EXECUTED, 1592.38
# 2020-04-02 SELL EXECUTED, 1587.48
# 2020-04-02 Bracket order placed: Entry 1585.38, SL 1580.38, TP 1595.38
# 2020-04-02 BUY EXECUTED, 1585.46
# 2020-04-02 SELL EXECUTED, 1595.38
# 2020-04-02 Bracket order placed: Entry 1588.81, SL 1593.81, TP 1578.81
# 2020-04-02 SELL EXECUTED, 1588.90
# 2020-04-02 BUY EXECUTED, 1593.81
# 2020-04-02 Bracket order placed: Entry 1593.13, SL 1598.13, TP 1583.13
# 2020-04-02 SELL EXECUTED, 1593.05
# 2020-04-02 BUY EXECUTED, 1598.13
# 2020-04-02 Bracket order placed: Entry 1604.15, SL 1609.15, TP 1594.15
# 2020-04-02 SELL EXECUTED, 1604.53
# 2020-04-02 BUY EXECUTED, 1609.15
# 2020-04-02 Bracket order placed: Entry 1606.17, SL 1601.17, TP 1616.17
# 2020-04-02 BUY EXECUTED, 1605.93
# 2020-04-02 SELL EXECUTED, 1616.17
# 2020-04-02 Bracket order placed: Entry 1613.15, SL 1608.15, TP 1623.15
# 2020-04-02 BUY EXECUTED, 1613.05
# 2020-04-03 SELL EXECUTED, 1608.15
# 2020-04-03 Bracket order placed: Entry 1610.93, SL 1605.93, TP 1620.93
# 2020-04-03 BUY EXECUTED, 1611.01
# 2020-04-03 SELL EXECUTED, 1620.93
# 2020-04-03 Bracket order placed: Entry 1616.96, SL 1611.96, TP 1626.96
# 2020-04-03 BUY EXECUTED, 1617.04
# 2020-04-03 SELL EXECUTED, 1611.96
# 2020-04-03 Bracket order placed: Entry 1617.98, SL 1612.98, TP 1627.98
# 2020-04-03 BUY EXECUTED, 1617.77
# 2020-04-05 SELL EXECUTED, 1612.98
# 2020-04-05 Bracket order placed: Entry 1614.99, SL 1609.99, TP 1624.99
# 2020-04-05 BUY EXECUTED, 1614.89
# 2020-04-06 SELL EXECUTED, 1624.99
# 2020-04-06 Bracket order placed: Entry 1625.28, SL 1630.28, TP 1615.28
# 2020-04-06 SELL EXECUTED, 1625.37
# 2020-04-06 BUY EXECUTED, 1630.28
# 2020-04-06 Bracket order placed: Entry 1635.79, SL 1630.79, TP 1645.79
# 2020-04-06 BUY EXECUTED, 1635.70
# 2020-04-06 SELL EXECUTED, 1645.79
# 2020-04-06 Bracket order placed: Entry 1646.69, SL 1651.69, TP 1636.69
# 2020-04-06 SELL EXECUTED, 1646.77
# 2020-04-06 BUY EXECUTED, 1651.69
# 2020-04-06 Bracket order placed: Entry 1654.43, SL 1649.43, TP 1664.43
# 2020-04-06 BUY EXECUTED, 1654.53
# 2020-04-06 SELL EXECUTED, 1664.43
# 2020-04-06 Bracket order placed: Entry 1663.31, SL 1668.31, TP 1653.31
# 2020-04-06 SELL EXECUTED, 1663.23
# 2020-04-06 BUY EXECUTED, 1668.31
# 2020-04-06 Bracket order placed: Entry 1667.34, SL 1672.34, TP 1657.34
# 2020-04-06 SELL EXECUTED, 1667.24
# 2020-04-06 BUY EXECUTED, 1672.34
# 2020-04-06 Bracket order placed: Entry 1668.13, SL 1673.13, TP 1658.13
# 2020-04-06 SELL EXECUTED, 1667.95
# 2020-04-07 BUY EXECUTED, 1658.13
# 2020-04-07 Bracket order placed: Entry 1661.08, SL 1656.08, TP 1671.08
# 2020-04-07 BUY EXECUTED, 1660.97
# 2020-04-07 SELL EXECUTED, 1656.08
# 2020-04-07 Bracket order placed: Entry 1665.76, SL 1660.76, TP 1675.76
# 2020-04-07 BUY EXECUTED, 1665.68
# 2020-04-07 SELL EXECUTED, 1660.76
# 2020-04-07 Bracket order placed: Entry 1654.62, SL 1649.62, TP 1664.62
# 2020-04-07 BUY EXECUTED, 1654.72
# 2020-04-07 SELL EXECUTED, 1649.62
# 2020-04-07 Bracket order placed: Entry 1653.71, SL 1648.71, TP 1663.71
# 2020-04-07 BUY EXECUTED, 1653.80
# 2020-04-07 SELL EXECUTED, 1648.71
# 2020-04-07 Bracket order placed: Entry 1649.06, SL 1644.06, TP 1659.06
# 2020-04-07 BUY EXECUTED, 1648.98
# 2020-04-07 SELL EXECUTED, 1644.06
# 2020-04-07 Bracket order placed: Entry 1647.92, SL 1642.92, TP 1657.92
# 2020-04-07 BUY EXECUTED, 1647.83
# 2020-04-07 SELL EXECUTED, 1657.92
# 2020-04-07 Bracket order placed: Entry 1649.00, SL 1644.00, TP 1659.00
# 2020-04-07 BUY EXECUTED, 1648.88
# 2020-04-08 SELL EXECUTED, 1644.00
# 2020-04-08 Bracket order placed: Entry 1645.53, SL 1640.53, TP 1655.53
# 2020-04-08 BUY EXECUTED, 1645.45
# 2020-04-08 SELL EXECUTED, 1655.53
# 2020-04-08 Bracket order placed: Entry 1651.56, SL 1656.56, TP 1641.56
# 2020-04-08 SELL EXECUTED, 1651.47
# 2020-04-08 BUY EXECUTED, 1656.56
# 2020-04-08 Bracket order placed: Entry 1652.79, SL 1657.79, TP 1642.79
# 2020-04-08 SELL EXECUTED, 1652.55
# 2020-04-09 BUY EXECUTED, 1657.79
# 2020-04-09 Bracket order placed: Entry 1656.88, SL 1651.88, TP 1666.88
# 2020-04-09 BUY EXECUTED, 1656.80
# 2020-04-09 SELL EXECUTED, 1666.88
# 2020-04-09 Bracket order placed: Entry 1674.09, SL 1679.09, TP 1664.09
# 2020-04-09 SELL EXECUTED, 1674.00
# 2020-04-09 BUY EXECUTED, 1679.09
# 2020-04-09 Bracket order placed: Entry 1681.02, SL 1676.02, TP 1691.02
# 2020-04-09 BUY EXECUTED, 1680.85
# 2020-04-09 SELL EXECUTED, 1676.02
# 2020-04-09 Bracket order placed: Entry 1679.35, SL 1684.35, TP 1669.35
# 2020-04-09 SELL EXECUTED, 1679.27
# 2020-04-09 BUY EXECUTED, 1684.35
# 2020-04-09 Bracket order placed: Entry 1682.30, SL 1677.30, TP 1692.30
# 2020-04-09 BUY EXECUTED, 1682.58
# 2020-04-12 SELL EXECUTED, 1677.30
# 2020-04-12 Bracket order placed: Entry 1688.55, SL 1683.55, TP 1698.55
# 2020-04-12 BUY EXECUTED, 1688.46
# 2020-04-12 SELL EXECUTED, 1683.55
# 2020-04-12 Bracket order placed: Entry 1685.51, SL 1680.51, TP 1695.51
# 2020-04-12 BUY EXECUTED, 1685.26
# 2020-04-13 SELL EXECUTED, 1680.51
# 2020-04-13 Bracket order placed: Entry 1680.78, SL 1685.78, TP 1670.78
# 2020-04-13 SELL EXECUTED, 1680.87
# 2020-04-13 BUY EXECUTED, 1685.78
# 2020-04-13 Bracket order placed: Entry 1682.98, SL 1687.98, TP 1672.98
# 2020-04-13 SELL EXECUTED, 1682.71
# 2020-04-13 BUY EXECUTED, 1687.98
# 2020-04-16 Bracket order placed: Entry 1725.34, SL 1720.34, TP 1735.34
# 2020-04-16 BUY EXECUTED, 1725.61
# 2020-04-16 SELL EXECUTED, 1720.34
# 2020-04-16 Bracket order placed: Entry 1717.65, SL 1712.65, TP 1727.65
# 2020-04-16 BUY EXECUTED, 1717.57
# 2020-04-16 SELL EXECUTED, 1712.65
# 2020-04-16 Bracket order placed: Entry 1717.24, SL 1712.24, TP 1727.24
# 2020-04-16 BUY EXECUTED, 1717.35
# 2020-04-16 SELL EXECUTED, 1712.24
# 2020-04-16 Bracket order placed: Entry 1712.23, SL 1717.23, TP 1702.23
# 2020-04-16 SELL EXECUTED, 1712.15
# 2020-04-16 BUY EXECUTED, 1717.23
# 2020-04-16 Bracket order placed: Entry 1717.06, SL 1712.06, TP 1727.06
# 2020-04-16 BUY EXECUTED, 1716.87
# 2020-04-16 SELL EXECUTED, 1712.06
# 2020-04-16 Bracket order placed: Entry 1710.96, SL 1705.96, TP 1720.96
# 2020-04-16 BUY EXECUTED, 1710.88
# 2020-04-17 SELL EXECUTED, 1705.96
# 2020-04-17 Bracket order placed: Entry 1706.72, SL 1711.72, TP 1696.72
# 2020-04-17 SELL EXECUTED, 1706.80
# 2020-04-17 BUY EXECUTED, 1696.72
# 2020-04-17 Bracket order placed: Entry 1697.64, SL 1692.64, TP 1707.64
# 2020-04-17 BUY EXECUTED, 1697.90
# 2020-04-17 SELL EXECUTED, 1692.64
# 2020-04-17 Bracket order placed: Entry 1686.84, SL 1681.84, TP 1696.84
# 2020-04-17 BUY EXECUTED, 1686.92
# 2020-04-17 SELL EXECUTED, 1696.84
# 2020-04-17 Bracket order placed: Entry 1694.44, SL 1699.44, TP 1684.44
# 2020-04-17 SELL EXECUTED, 1694.35
# 2020-04-17 BUY EXECUTED, 1699.44
# 2020-04-17 Bracket order placed: Entry 1698.55, SL 1693.55, TP 1708.55
# 2020-04-17 BUY EXECUTED, 1698.73
# 2020-04-17 SELL EXECUTED, 1693.55
# 2020-04-17 Bracket order placed: Entry 1690.38, SL 1695.38, TP 1680.38
# 2020-04-17 SELL EXECUTED, 1690.52
# 2020-04-17 BUY EXECUTED, 1680.38
# 2020-04-17 Bracket order placed: Entry 1685.30, SL 1680.30, TP 1695.30
# 2020-04-17 BUY EXECUTED, 1685.10
# 2020-04-17 SELL EXECUTED, 1680.30
# 2020-04-17 Bracket order placed: Entry 1683.35, SL 1678.35, TP 1693.35
# 2020-04-17 BUY EXECUTED, 1683.18
# 2020-04-19 SELL EXECUTED, 1678.35
# 2020-04-19 Bracket order placed: Entry 1676.43, SL 1681.43, TP 1666.43
# 2020-04-19 SELL EXECUTED, 1676.51
# 2020-04-20 BUY EXECUTED, 1681.43
# 2020-04-20 Bracket order placed: Entry 1681.39, SL 1686.39, TP 1671.39
# 2020-04-20 SELL EXECUTED, 1681.20
# 2020-04-20 BUY EXECUTED, 1686.39
# 2020-04-20 Bracket order placed: Entry 1686.79, SL 1681.79, TP 1696.79
# 2020-04-20 BUY EXECUTED, 1686.89
# 2020-04-20 SELL EXECUTED, 1696.79
# 2020-04-20 Bracket order placed: Entry 1695.01, SL 1690.01, TP 1705.01
# 2020-04-20 BUY EXECUTED, 1695.11
# 2020-04-20 SELL EXECUTED, 1690.01
# 2020-04-20 Bracket order placed: Entry 1690.86, SL 1695.86, TP 1680.86
# 2020-04-20 SELL EXECUTED, 1690.94
# 2020-04-20 BUY EXECUTED, 1695.86
# 2020-04-20 Bracket order placed: Entry 1695.96, SL 1700.96, TP 1685.96
# 2020-04-20 SELL EXECUTED, 1695.65
# 2020-04-21 BUY EXECUTED, 1685.96
# 2020-04-21 Bracket order placed: Entry 1677.06, SL 1682.06, TP 1667.06
# 2020-04-21 SELL EXECUTED, 1677.14
# 2020-04-21 BUY EXECUTED, 1667.06
# 2020-04-21 Bracket order placed: Entry 1672.03, SL 1677.03, TP 1662.03
# 2020-04-21 SELL EXECUTED, 1672.12
# 2020-04-21 BUY EXECUTED, 1677.03
# 2020-04-21 Bracket order placed: Entry 1681.16, SL 1686.16, TP 1671.16
# 2020-04-21 SELL EXECUTED, 1681.06
# 2020-04-21 BUY EXECUTED, 1686.16
# 2020-04-21 Bracket order placed: Entry 1682.69, SL 1687.69, TP 1672.69
# 2020-04-21 SELL EXECUTED, 1682.54
# 2020-04-21 BUY EXECUTED, 1687.77
# 2020-04-21 Bracket order placed: Entry 1686.84, SL 1681.84, TP 1696.84
# 2020-04-21 BUY EXECUTED, 1686.96
# 2020-04-22 SELL EXECUTED, 1681.84
# 2020-04-22 Bracket order placed: Entry 1683.48, SL 1678.48, TP 1693.48
# 2020-04-22 BUY EXECUTED, 1683.59
# 2020-04-22 SELL EXECUTED, 1693.48
# 2020-04-22 Bracket order placed: Entry 1701.71, SL 1706.71, TP 1691.71
# 2020-04-22 SELL EXECUTED, 1701.62
# 2020-04-22 BUY EXECUTED, 1706.71
# 2020-04-22 Bracket order placed: Entry 1704.76, SL 1699.76, TP 1714.76
# 2020-04-22 BUY EXECUTED, 1704.58
# 2020-04-22 SELL EXECUTED, 1714.76
# 2020-04-22 Bracket order placed: Entry 1712.86, SL 1707.86, TP 1722.86
# 2020-04-22 BUY EXECUTED, 1713.08
# 2020-04-23 SELL EXECUTED, 1707.86
# 2020-04-23 Bracket order placed: Entry 1715.19, SL 1720.19, TP 1705.19
# 2020-04-23 SELL EXECUTED, 1715.11
# 2020-04-23 BUY EXECUTED, 1720.19
# 2020-04-23 Bracket order placed: Entry 1725.84, SL 1720.84, TP 1735.84
# 2020-04-23 BUY EXECUTED, 1725.46
# 2020-04-23 SELL EXECUTED, 1720.84
# 2020-04-23 Bracket order placed: Entry 1723.73, SL 1728.73, TP 1713.73
# 2020-04-23 SELL EXECUTED, 1723.95
# 2020-04-23 BUY EXECUTED, 1728.73
# 2020-04-23 Bracket order placed: Entry 1733.11, SL 1728.11, TP 1743.11
# 2020-04-23 BUY EXECUTED, 1733.20
# 2020-04-23 SELL EXECUTED, 1728.11
# 2020-04-24 Bracket order placed: Entry 1723.60, SL 1728.60, TP 1713.60
# 2020-04-24 SELL EXECUTED, 1723.72
# 2020-04-24 BUY EXECUTED, 1728.60
# 2020-04-24 Bracket order placed: Entry 1728.68, SL 1733.68, TP 1718.68
# 2020-04-24 SELL EXECUTED, 1728.59
# 2020-04-24 BUY EXECUTED, 1733.68
# 2020-04-24 Bracket order placed: Entry 1732.94, SL 1737.94, TP 1722.94
# 2020-04-24 SELL EXECUTED, 1732.74
# 2020-04-24 BUY EXECUTED, 1722.94
# 2020-04-24 Bracket order placed: Entry 1724.59, SL 1719.59, TP 1734.59
# 2020-04-24 BUY EXECUTED, 1724.65
# 2020-04-26 SELL EXECUTED, 1719.59
# 2020-04-26 Bracket order placed: Entry 1722.77, SL 1717.77, TP 1732.77
# 2020-04-26 BUY EXECUTED, 1722.85
# 2020-04-27 SELL EXECUTED, 1717.77
# 2020-04-27 Bracket order placed: Entry 1719.57, SL 1714.57, TP 1729.57
# 2020-04-27 BUY EXECUTED, 1719.67
# 2020-04-27 SELL EXECUTED, 1714.57
# 2020-04-27 Bracket order placed: Entry 1719.65, SL 1724.65, TP 1709.65
# 2020-04-27 SELL EXECUTED, 1719.73
# 2020-04-27 BUY EXECUTED, 1709.65
# 2020-04-27 Bracket order placed: Entry 1713.46, SL 1708.46, TP 1723.46
# 2020-04-27 BUY EXECUTED, 1713.41
# 2020-04-27 SELL EXECUTED, 1708.46
# 2020-04-28 Bracket order placed: Entry 1709.33, SL 1704.33, TP 1719.33
# 2020-04-28 BUY EXECUTED, 1709.42
# 2020-04-28 SELL EXECUTED, 1704.33
# 2020-04-28 Bracket order placed: Entry 1703.93, SL 1698.93, TP 1713.93
# 2020-04-28 BUY EXECUTED, 1704.01
# 2020-04-28 SELL EXECUTED, 1698.93
# 2020-04-28 Bracket order placed: Entry 1697.59, SL 1692.59, TP 1707.59
# 2020-04-28 BUY EXECUTED, 1697.68
# 2020-04-28 SELL EXECUTED, 1692.59
# 2020-04-28 Bracket order placed: Entry 1695.72, SL 1690.72, TP 1705.72
# 2020-04-28 BUY EXECUTED, 1695.63
# 2020-04-28 SELL EXECUTED, 1705.72
# 2020-04-28 Bracket order placed: Entry 1708.08, SL 1713.08, TP 1698.08
# 2020-04-28 SELL EXECUTED, 1708.00
# 2020-04-28 BUY EXECUTED, 1713.08
# 2020-04-28 Bracket order placed: Entry 1701.78, SL 1706.78, TP 1691.78
# 2020-04-28 SELL EXECUTED, 1701.87
# 2020-04-28 BUY EXECUTED, 1706.78
# 2020-04-28 Bracket order placed: Entry 1705.95, SL 1700.95, TP 1715.95
# 2020-04-28 BUY EXECUTED, 1706.05
# 2020-04-29 SELL EXECUTED, 1700.95
# 2020-04-29 Bracket order placed: Entry 1702.69, SL 1707.69, TP 1692.69
# 2020-04-29 SELL EXECUTED, 1703.04
# ...
# 2025-03-31 Bracket order placed: Entry 3119.39, SL 3114.39, TP 3129.39
# 2025-03-31 BUY EXECUTED, 3119.41
# 2025-03-31 SELL EXECUTED, 3114.39
# 2025-03-31 Bracket order placed: Entry 3116.78, SL 3111.78, TP 3126.78
# 2025-03-31 BUY EXECUTED, 3116.83
# 2025-03-31 SELL EXECUTED, 3111.78
# 2025-03-31 Bracket order placed: Entry 3112.72, SL 3107.72, TP 3122.72
# 2025-03-31 BUY EXECUTED, 3112.78
# 2025-03-31 SELL EXECUTED, 3122.72
# 2025-03-31 Bracket order placed: Entry 3119.46, SL 3124.46, TP 3109.46
# 2025-03-31 SELL EXECUTED, 3119.45
# 2025-03-31 BUY EXECUTED, 3124.46
# 2025-03-31 Bracket order placed: Entry 3124.94, SL 3119.94, TP 3134.94
# 2025-03-31 BUY EXECUTED, 3124.92
# 2025-04-01 SELL EXECUTED, 3134.94
# 2025-04-01 Bracket order placed: Entry 3144.08, SL 3149.08, TP 3134.08
# 2025-04-01 SELL EXECUTED, 3144.09
# 2025-04-01 BUY EXECUTED, 3149.08
# 2025-04-01 Bracket order placed: Entry 3143.01, SL 3148.01, TP 3133.01
# 2025-04-01 SELL EXECUTED, 3142.99
# 2025-04-01 BUY EXECUTED, 3133.01
# 2025-04-01 Bracket order placed: Entry 3136.37, SL 3131.37, TP 3146.37
# 2025-04-01 BUY EXECUTED, 3136.38
# 2025-04-01 SELL EXECUTED, 3131.37
# 2025-04-01 Bracket order placed: Entry 3134.06, SL 3139.06, TP 3124.06
# 2025-04-01 SELL EXECUTED, 3134.02
# 2025-04-01 BUY EXECUTED, 3139.06
# 2025-04-01 Bracket order placed: Entry 3134.00, SL 3139.00, TP 3124.00
# 2025-04-01 SELL EXECUTED, 3133.98
# 2025-04-01 BUY EXECUTED, 3124.00
# 2025-04-01 Bracket order placed: Entry 3128.99, SL 3133.99, TP 3118.99
# 2025-04-01 SELL EXECUTED, 3129.05
# 2025-04-01 BUY EXECUTED, 3118.99
# 2025-04-01 Bracket order placed: Entry 3108.69, SL 3103.69, TP 3118.69
# 2025-04-01 BUY EXECUTED, 3108.69
# 2025-04-01 SELL EXECUTED, 3118.69
# 2025-04-01 Bracket order placed: Entry 3116.01, SL 3111.01, TP 3126.01
# 2025-04-01 BUY EXECUTED, 3116.02
# 2025-04-01 SELL EXECUTED, 3111.01
# 2025-04-01 Bracket order placed: Entry 3112.61, SL 3117.61, TP 3102.61
# 2025-04-01 SELL EXECUTED, 3112.61
# 2025-04-02 BUY EXECUTED, 3117.61
# 2025-04-02 Bracket order placed: Entry 3116.42, SL 3111.42, TP 3126.42
# 2025-04-02 BUY EXECUTED, 3116.58
# 2025-04-02 SELL EXECUTED, 3126.42
# 2025-04-02 Bracket order placed: Entry 3129.01, SL 3134.01, TP 3119.01
# 2025-04-02 SELL EXECUTED, 3129.01
# 2025-04-02 BUY EXECUTED, 3119.01
# 2025-04-02 Bracket order placed: Entry 3120.95, SL 3115.95, TP 3130.95
# 2025-04-02 BUY EXECUTED, 3121.03
# 2025-04-02 SELL EXECUTED, 3130.95
# 2025-04-02 Bracket order placed: Entry 3119.70, SL 3124.70, TP 3109.70
# 2025-04-02 SELL EXECUTED, 3119.75
# 2025-04-02 BUY EXECUTED, 3124.70
# 2025-04-02 Bracket order placed: Entry 3126.48, SL 3121.48, TP 3136.48
# 2025-04-02 BUY EXECUTED, 3126.51
# 2025-04-02 SELL EXECUTED, 3121.48
# 2025-04-02 Bracket order placed: Entry 3128.16, SL 3123.16, TP 3138.16
# 2025-04-02 BUY EXECUTED, 3128.15
# 2025-04-02 SELL EXECUTED, 3123.16
# 2025-04-02 Bracket order placed: Entry 3124.39, SL 3119.39, TP 3134.39
# 2025-04-02 BUY EXECUTED, 3124.39
# 2025-04-02 SELL EXECUTED, 3119.39
# 2025-04-02 Bracket order placed: Entry 3122.60, SL 3117.60, TP 3132.60
# 2025-04-02 BUY EXECUTED, 3122.60
# 2025-04-02 SELL EXECUTED, 3132.60
# 2025-04-03 Bracket order placed: Entry 3154.69, SL 3159.69, TP 3144.69
# 2025-04-03 SELL EXECUTED, 3154.70
# 2025-04-03 BUY EXECUTED, 3144.69
# 2025-04-03 Bracket order placed: Entry 3153.05, SL 3148.05, TP 3163.05
# 2025-04-03 BUY EXECUTED, 3153.10
# 2025-04-03 SELL EXECUTED, 3148.05
# 2025-04-03 Bracket order placed: Entry 3152.89, SL 3157.89, TP 3142.89
# 2025-04-03 SELL EXECUTED, 3152.88
# 2025-04-03 BUY EXECUTED, 3142.89
# 2025-04-03 Bracket order placed: Entry 3148.27, SL 3143.27, TP 3158.27
# 2025-04-03 BUY EXECUTED, 3148.29
# 2025-04-03 SELL EXECUTED, 3143.27
# 2025-04-03 Bracket order placed: Entry 3128.37, SL 3133.37, TP 3118.37
# 2025-04-03 SELL EXECUTED, 3128.41
# 2025-04-03 BUY EXECUTED, 3118.37
# 2025-04-03 Bracket order placed: Entry 3124.12, SL 3129.12, TP 3114.12
# 2025-04-03 SELL EXECUTED, 3124.16
# 2025-04-03 BUY EXECUTED, 3129.12
# 2025-04-03 Bracket order placed: Entry 3129.11, SL 3134.11, TP 3119.11
# 2025-04-03 SELL EXECUTED, 3129.11
# 2025-04-03 BUY EXECUTED, 3119.11
# 2025-04-03 Bracket order placed: Entry 3070.61, SL 3065.61, TP 3080.61
# 2025-04-03 BUY EXECUTED, 3070.70
# 2025-04-03 SELL EXECUTED, 3085.38
# 2025-04-03 Bracket order placed: Entry 3111.56, SL 3116.56, TP 3101.56
# 2025-04-03 SELL EXECUTED, 3111.62
# 2025-04-03 BUY EXECUTED, 3101.56
# 2025-04-03 Bracket order placed: Entry 3106.67, SL 3101.67, TP 3116.67
# 2025-04-03 BUY EXECUTED, 3106.58
# 2025-04-03 SELL EXECUTED, 3116.67
# 2025-04-03 Bracket order placed: Entry 3114.52, SL 3109.52, TP 3124.52
# 2025-04-03 BUY EXECUTED, 3114.51
# 2025-04-04 SELL EXECUTED, 3109.52
# 2025-04-04 Bracket order placed: Entry 3112.81, SL 3107.81, TP 3122.81
# 2025-04-04 BUY EXECUTED, 3112.78
# 2025-04-04 SELL EXECUTED, 3107.81
# 2025-04-04 Bracket order placed: Entry 3110.79, SL 3115.79, TP 3100.79
# 2025-04-04 SELL EXECUTED, 3110.73
# 2025-04-04 BUY EXECUTED, 3100.79
# 2025-04-04 Bracket order placed: Entry 3096.31, SL 3091.31, TP 3106.31
# 2025-04-04 BUY EXECUTED, 3096.31
# 2025-04-04 SELL EXECUTED, 3106.31
# 2025-04-04 Bracket order placed: Entry 3115.06, SL 3120.06, TP 3105.06
# 2025-04-04 SELL EXECUTED, 3115.18
# 2025-04-04 BUY EXECUTED, 3105.06
# 2025-04-04 Bracket order placed: Entry 3024.68, SL 3019.68, TP 3034.68
# 2025-04-04 BUY EXECUTED, 3024.78
# 2025-04-04 SELL EXECUTED, 3019.68
# 2025-04-04 Bracket order placed: Entry 3023.85, SL 3018.85, TP 3033.85
# 2025-04-04 BUY EXECUTED, 3023.82
# 2025-04-04 SELL EXECUTED, 3033.85
# 2025-04-06 Bracket order placed: Entry 3029.92, SL 3034.92, TP 3019.92
# 2025-04-06 SELL EXECUTED, 3029.48
# 2025-04-06 BUY EXECUTED, 3014.84
# 2025-04-07 Bracket order placed: Entry 2988.23, SL 2993.23, TP 2978.23
# 2025-04-07 SELL EXECUTED, 2988.25
# 2025-04-07 BUY EXECUTED, 2978.23
# 2025-04-07 Bracket order placed: Entry 2993.04, SL 2988.04, TP 3003.04
# 2025-04-07 BUY EXECUTED, 2993.03
# 2025-04-07 SELL EXECUTED, 3007.04
# 2025-04-07 Bracket order placed: Entry 3036.30, SL 3041.30, TP 3026.30
# 2025-04-07 SELL EXECUTED, 3036.38
# 2025-04-07 BUY EXECUTED, 3026.30
# 2025-04-07 Bracket order placed: Entry 3034.67, SL 3039.67, TP 3024.67
# 2025-04-07 SELL EXECUTED, 3034.66
# 2025-04-07 BUY EXECUTED, 3024.67
# 2025-04-07 Bracket order placed: Entry 3027.78, SL 3032.78, TP 3017.78
# 2025-04-07 SELL EXECUTED, 3027.67
# 2025-04-07 BUY EXECUTED, 3017.78
# 2025-04-07 Bracket order placed: Entry 3022.20, SL 3017.20, TP 3032.20
# 2025-04-07 BUY EXECUTED, 3022.14
# 2025-04-07 SELL EXECUTED, 3032.20
# 2025-04-07 Bracket order placed: Entry 3027.22, SL 3022.22, TP 3037.22
# 2025-04-07 BUY EXECUTED, 3027.21
# 2025-04-07 SELL EXECUTED, 3037.22
# 2025-04-07 Bracket order placed: Entry 3036.06, SL 3041.06, TP 3026.06
# 2025-04-07 SELL EXECUTED, 3036.20
# 2025-04-07 BUY EXECUTED, 3026.06
# 2025-04-07 Bracket order placed: Entry 3024.79, SL 3029.79, TP 3014.79
# 2025-04-07 SELL EXECUTED, 3024.48
# 2025-04-07 BUY EXECUTED, 3014.79
# 2025-04-07 Bracket order placed: Entry 3027.19, SL 3022.19, TP 3037.19
# 2025-04-07 BUY EXECUTED, 3027.20
# 2025-04-07 SELL EXECUTED, 3022.19
# 2025-04-07 Bracket order placed: Entry 3007.77, SL 3012.77, TP 2997.77
# 2025-04-07 SELL EXECUTED, 3007.95
# 2025-04-07 BUY EXECUTED, 2997.77
# 2025-04-07 Bracket order placed: Entry 2979.25, SL 2984.25, TP 2969.25
# 2025-04-07 SELL EXECUTED, 2979.30
# 2025-04-07 BUY EXECUTED, 2969.25
# 2025-04-07 Bracket order placed: Entry 2970.35, SL 2975.35, TP 2960.35
# 2025-04-07 SELL EXECUTED, 2970.30
# 2025-04-07 BUY EXECUTED, 2975.35
# 2025-04-07 Bracket order placed: Entry 2985.75, SL 2980.75, TP 2995.75
# 2025-04-07 BUY EXECUTED, 2985.70
# 2025-04-07 SELL EXECUTED, 2980.75
# 2025-04-08 Bracket order placed: Entry 2990.74, SL 2985.74, TP 3000.74
# 2025-04-08 BUY EXECUTED, 2990.68
# 2025-04-08 SELL EXECUTED, 3000.74
# 2025-04-08 Bracket order placed: Entry 3001.06, SL 3006.06, TP 2991.06
# 2025-04-08 SELL EXECUTED, 3001.04
# 2025-04-08 BUY EXECUTED, 2991.06
# 2025-04-08 Bracket order placed: Entry 2997.81, SL 2992.81, TP 3007.81
# 2025-04-08 BUY EXECUTED, 2997.81
# 2025-04-08 SELL EXECUTED, 3007.81
# 2025-04-08 Bracket order placed: Entry 3011.78, SL 3006.78, TP 3021.78
# 2025-04-08 BUY EXECUTED, 3011.75
# 2025-04-08 SELL EXECUTED, 3006.78
# 2025-04-08 Bracket order placed: Entry 3007.92, SL 3002.92, TP 3017.92
# 2025-04-08 BUY EXECUTED, 3007.82
# 2025-04-08 SELL EXECUTED, 3002.92
# 2025-04-08 Bracket order placed: Entry 3005.67, SL 3010.67, TP 2995.67
# 2025-04-08 SELL EXECUTED, 3005.65
# 2025-04-08 BUY EXECUTED, 2995.67
# 2025-04-08 Bracket order placed: Entry 3004.12, SL 2999.12, TP 3014.12
# 2025-04-08 BUY EXECUTED, 3004.10
# 2025-04-08 SELL EXECUTED, 3014.13
# 2025-04-08 Bracket order placed: Entry 3010.96, SL 3005.96, TP 3020.96
# 2025-04-08 BUY EXECUTED, 3011.00
# 2025-04-08 SELL EXECUTED, 3005.96
# 2025-04-08 Bracket order placed: Entry 3018.61, SL 3013.61, TP 3028.61
# 2025-04-08 BUY EXECUTED, 3018.41
# 2025-04-08 SELL EXECUTED, 3013.61
# 2025-04-08 Bracket order placed: Entry 3010.66, SL 3015.66, TP 3000.66
# 2025-04-08 SELL EXECUTED, 3010.72
# 2025-04-08 BUY EXECUTED, 3015.66
# 2025-04-08 Bracket order placed: Entry 3011.61, SL 3016.61, TP 3001.61
# 2025-04-08 SELL EXECUTED, 3011.60
# 2025-04-08 BUY EXECUTED, 3016.61
# 2025-04-08 Bracket order placed: Entry 3009.35, SL 3014.35, TP 2999.35
# 2025-04-08 SELL EXECUTED, 3009.35
# 2025-04-08 BUY EXECUTED, 2999.35
# 2025-04-08 Bracket order placed: Entry 2983.32, SL 2978.32, TP 2993.32
# 2025-04-08 BUY EXECUTED, 2983.35
# 2025-04-08 SELL EXECUTED, 2978.32
# 2025-04-08 Bracket order placed: Entry 2983.15, SL 2978.15, TP 2993.15
# 2025-04-08 BUY EXECUTED, 2983.24
# 2025-04-08 SELL EXECUTED, 2978.15
# 2025-04-08 Bracket order placed: Entry 2981.03, SL 2986.03, TP 2971.03
# 2025-04-08 SELL EXECUTED, 2981.06
# 2025-04-08 BUY EXECUTED, 2986.03
# 2025-04-08 Bracket order placed: Entry 2982.29, SL 2987.29, TP 2972.29
# 2025-04-08 SELL EXECUTED, 2982.27
# 2025-04-08 BUY EXECUTED, 2972.29
# 2025-04-09 Bracket order placed: Entry 2979.32, SL 2974.32, TP 2989.32
# 2025-04-09 BUY EXECUTED, 2979.31
# 2025-04-09 SELL EXECUTED, 2974.32
# 2025-04-09 Bracket order placed: Entry 2979.97, SL 2974.97, TP 2989.97
# 2025-04-09 BUY EXECUTED, 2979.98
# 2025-04-09 SELL EXECUTED, 2989.97
# 2025-04-09 Bracket order placed: Entry 3005.66, SL 3000.66, TP 3015.66
# 2025-04-09 BUY EXECUTED, 3005.36
# 2025-04-09 SELL EXECUTED, 3000.66
# 2025-04-09 Bracket order placed: Entry 3009.00, SL 3004.00, TP 3019.00
# 2025-04-09 BUY EXECUTED, 3009.00
# 2025-04-09 SELL EXECUTED, 3019.00
# 2025-04-09 Bracket order placed: Entry 3044.04, SL 3039.04, TP 3054.04
# 2025-04-09 BUY EXECUTED, 3044.03
# 2025-04-09 SELL EXECUTED, 3039.04
# 2025-04-09 Bracket order placed: Entry 3045.91, SL 3040.91, TP 3055.91
# 2025-04-09 BUY EXECUTED, 3045.93
# 2025-04-09 SELL EXECUTED, 3040.91
# 2025-04-09 Bracket order placed: Entry 3043.01, SL 3038.01, TP 3053.01
# 2025-04-09 BUY EXECUTED, 3042.98
# 2025-04-09 SELL EXECUTED, 3053.01
# 2025-04-09 Bracket order placed: Entry 3061.11, SL 3066.11, TP 3051.11
# 2025-04-09 SELL EXECUTED, 3061.09
# 2025-04-09 BUY EXECUTED, 3051.11
# 2025-04-09 Bracket order placed: Entry 3055.93, SL 3050.93, TP 3065.93
# 2025-04-09 BUY EXECUTED, 3055.94
# 2025-04-09 SELL EXECUTED, 3065.93
# 2025-04-09 Bracket order placed: Entry 3082.75, SL 3077.75, TP 3092.75
# 2025-04-09 BUY EXECUTED, 3082.73
# 2025-04-09 SELL EXECUTED, 3092.75
# 2025-04-09 Bracket order placed: Entry 3087.60, SL 3092.60, TP 3077.60
# 2025-04-09 SELL EXECUTED, 3087.60
# 2025-04-09 BUY EXECUTED, 3092.60
# 2025-04-09 Bracket order placed: Entry 3072.36, SL 3077.36, TP 3062.36
# 2025-04-09 SELL EXECUTED, 3072.31
# 2025-04-09 BUY EXECUTED, 3060.30
# 2025-04-09 Bracket order placed: Entry 3070.16, SL 3065.16, TP 3080.16
# 2025-04-09 BUY EXECUTED, 3070.30
# 2025-04-09 SELL EXECUTED, 3065.16
# 2025-04-09 Bracket order placed: Entry 3089.39, SL 3094.39, TP 3079.39
# 2025-04-09 SELL EXECUTED, 3089.42
# 2025-04-09 BUY EXECUTED, 3079.39
# 2025-04-09 Bracket order placed: Entry 3081.44, SL 3076.44, TP 3091.44
# 2025-04-09 BUY EXECUTED, 3081.42
# 2025-04-10 SELL EXECUTED, 3091.44
# 2025-04-10 Bracket order placed: Entry 3092.05, SL 3097.05, TP 3082.05
# 2025-04-10 SELL EXECUTED, 3092.04
# 2025-04-10 BUY EXECUTED, 3082.05
# 2025-04-10 Bracket order placed: Entry 3093.48, SL 3088.48, TP 3103.48
# 2025-04-10 BUY EXECUTED, 3093.47
# 2025-04-10 SELL EXECUTED, 3103.48
# 2025-04-10 Bracket order placed: Entry 3126.23, SL 3121.23, TP 3136.23
# 2025-04-10 BUY EXECUTED, 3126.16
# 2025-04-10 SELL EXECUTED, 3121.23
# 2025-04-10 Bracket order placed: Entry 3126.27, SL 3121.27, TP 3136.27
# 2025-04-10 BUY EXECUTED, 3126.03
# 2025-04-10 SELL EXECUTED, 3121.27
# 2025-04-10 Bracket order placed: Entry 3121.15, SL 3126.15, TP 3111.15
# 2025-04-10 SELL EXECUTED, 3121.14
# 2025-04-10 BUY EXECUTED, 3111.15
# 2025-04-10 Bracket order placed: Entry 3108.07, SL 3113.07, TP 3098.07
# 2025-04-10 SELL EXECUTED, 3108.04
# 2025-04-10 BUY EXECUTED, 3113.07
# 2025-04-10 Bracket order placed: Entry 3119.13, SL 3114.13, TP 3129.13
# 2025-04-10 BUY EXECUTED, 3119.15
# 2025-04-10 SELL EXECUTED, 3114.13
# 2025-04-10 Bracket order placed: Entry 3124.82, SL 3119.82, TP 3134.82
# 2025-04-10 BUY EXECUTED, 3124.81
# 2025-04-10 SELL EXECUTED, 3134.82
# 2025-04-10 Bracket order placed: Entry 3135.12, SL 3130.12, TP 3145.12
# 2025-04-10 BUY EXECUTED, 3135.13
# 2025-04-10 SELL EXECUTED, 3145.12
# 2025-04-10 Bracket order placed: Entry 3164.74, SL 3159.74, TP 3174.74
# 2025-04-10 BUY EXECUTED, 3164.70
# 2025-04-10 SELL EXECUTED, 3159.74
# 2025-04-10 Bracket order placed: Entry 3158.45, SL 3163.45, TP 3148.45
# 2025-04-10 SELL EXECUTED, 3158.44
# 2025-04-10 BUY EXECUTED, 3163.45
# 2025-04-10 Bracket order placed: Entry 3160.37, SL 3165.37, TP 3150.37
# 2025-04-10 SELL EXECUTED, 3160.36
# 2025-04-10 BUY EXECUTED, 3165.37
# 2025-04-10 Bracket order placed: Entry 3164.15, SL 3159.15, TP 3174.15
# 2025-04-10 BUY EXECUTED, 3164.16
# 2025-04-10 SELL EXECUTED, 3174.15
# 2025-04-10 Bracket order placed: Entry 3174.23, SL 3169.23, TP 3184.23
# 2025-04-10 BUY EXECUTED, 3174.28
# 2025-04-10 SELL EXECUTED, 3169.23
# 2025-04-10 Bracket order placed: Entry 3174.92, SL 3169.92, TP 3184.92
# 2025-04-10 BUY EXECUTED, 3174.91
# 2025-04-10 SELL EXECUTED, 3184.92
# 2025-04-10 Bracket order placed: Entry 3188.07, SL 3183.07, TP 3198.07
# 2025-04-10 BUY EXECUTED, 3188.08
# 2025-04-11 SELL EXECUTED, 3198.07
# 2025-04-11 Bracket order placed: Entry 3210.24, SL 3215.24, TP 3200.24
# 2025-04-11 SELL EXECUTED, 3210.25
# 2025-04-11 BUY EXECUTED, 3215.24
# 2025-04-11 Bracket order placed: Entry 3218.33, SL 3213.33, TP 3228.33
# 2025-04-11 BUY EXECUTED, 3218.31
# 2025-04-11 SELL EXECUTED, 3213.33
# 2025-04-11 Bracket order placed: Entry 3215.69, SL 3210.69, TP 3225.69
# 2025-04-11 BUY EXECUTED, 3215.69
# 2025-04-11 SELL EXECUTED, 3210.69
# 2025-04-11 Bracket order placed: Entry 3207.61, SL 3212.61, TP 3197.61
# 2025-04-11 SELL EXECUTED, 3207.60
# 2025-04-11 BUY EXECUTED, 3189.30
# 2025-04-11 Bracket order placed: Entry 3207.25, SL 3202.25, TP 3217.25
# 2025-04-11 BUY EXECUTED, 3207.25
# 2025-04-11 SELL EXECUTED, 3217.25
# 2025-04-11 Bracket order placed: Entry 3216.09, SL 3221.09, TP 3206.09
# 2025-04-11 SELL EXECUTED, 3216.07
# 2025-04-11 BUY EXECUTED, 3221.09
# 2025-04-11 Bracket order placed: Entry 3221.72, SL 3216.72, TP 3231.72
# 2025-04-11 BUY EXECUTED, 3221.78
# 2025-04-11 SELL EXECUTED, 3231.72
# 2025-04-11 Bracket order placed: Entry 3225.14, SL 3230.14, TP 3215.14
# 2025-04-11 SELL EXECUTED, 3225.14
# 2025-04-11 BUY EXECUTED, 3215.14
# 2025-04-11 Bracket order placed: Entry 3218.70, SL 3223.70, TP 3208.70
# 2025-04-11 SELL EXECUTED, 3218.82
# 2025-04-11 BUY EXECUTED, 3223.70
# 2025-04-11 Bracket order placed: Entry 3230.30, SL 3235.30, TP 3220.30
# 2025-04-11 SELL EXECUTED, 3230.38
# 2025-04-11 BUY EXECUTED, 3220.30
# 2025-04-11 Bracket order placed: Entry 3232.48, SL 3227.48, TP 3242.48
# 2025-04-11 BUY EXECUTED, 3232.52
# 2025-04-11 SELL EXECUTED, 3227.48
# 2025-04-11 Bracket order placed: Entry 3230.23, SL 3225.23, TP 3240.23
# 2025-04-11 BUY EXECUTED, 3230.19
# 2025-04-11 SELL EXECUTED, 3240.23
# 2025-04-11 Bracket order placed: Entry 3234.48, SL 3239.48, TP 3224.48
# 2025-04-11 SELL EXECUTED, 3234.48
# 2025-04-11 BUY EXECUTED, 3224.48
# 2025-04-11 Bracket order placed: Entry 3234.30, SL 3229.30, TP 3244.30
# 2025-04-11 BUY EXECUTED, 3234.26
# 2025-04-11 SELL EXECUTED, 3229.30
# 2025-04-11 Bracket order placed: Entry 3232.42, SL 3227.42, TP 3242.42
# 2025-04-11 BUY EXECUTED, 3232.43

# %%
strat = results[0]
sharpe_ratio = strat.analyzers.sharperatio.get_analysis()
drawdown = strat.analyzers.drawdown.get_analysis()
trade_analysis = strat.analyzers.tradeanalyzer.get_analysis()
returns = strat.analyzers.returns.get_analysis()
print(f'Sharpe Ratio: {sharpe_ratio}')
print(f'Max Drawdown: {drawdown["max"]["drawdown"]}')
print(f'Number of Trades: {trade_analysis.total.closed}')
print(f'Winning Trades: {trade_analysis.won.total}')
print(f'Losing Trades: {trade_analysis.lost.total}')
print(f'Average Trade Return: {returns["rnorm"]}')
# Out:
# Sharpe Ratio: OrderedDict({'sharperatio': -122.31271677207444})
# Max Drawdown: 0.1499822792125559
# Number of Trades: 4892
# Winning Trades: 1949
# Losing Trades: 2943
# Average Trade Return: -0.00023427156234810372

# %%
fig = cerebro.plot(iplot=True)
plt.show()
fig
