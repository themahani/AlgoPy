# %%
import backtrader as bt
import pandas as pd
import pandas_ta as ta
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
class VWAPStrategy(bt.Strategy):
    params = (
        ("ema_period", 50),     # EMA Period
        ('atr_period', 9) ,      # ATR Period
        ('atr_multiplier', 1.5), # ATR multiplier for SL calculation
        ("stop_loss", 0.02),  # 2% stop loss
        ("risk", 0.01),  # 1% risk
        ("pivot_window", 5),  # 5 bars for pivot high/low
        ("rrr", 2),  # Risk-Reward Ratio
        ("trailpercent", 0.05),     # Percent Price for Trailing stop
        ("sl_pips", 50),
        ("pip_value", 0.01)     # Pip value for Gold (XAUUSD)
    )
    def __init__(self):
        # initialize the EMA indicator on data feed
        # self.ema = bt.talib.EMA(self.data.close, self.params.ema_period)
        self.ema = bt.indicators.ExponentialMovingAverage(period=self.params.ema_period)
        self.atr = bt.indicators.AverageTrueRange(period=self.params.atr_period)
        self.crossover = bt.indicators.CrossOver(self.data.close, self.ema)
        self.order = None
        self.prev_pivot_high = self.data.low[0]
        self.prev_pivot_low = self.data.high[0]
        
    def _isBulluish(self, idx:int):
        if len(self) < idx:
            self.log("[Error]: Index out of bounds for `isBullish`")
        return self.data.close[idx] > self.data.open[idx]

    def _isEngulfing(self, idx:int):
        if len(self) < idx:
            self.log("[Error]: Index out of bounds for `isEnglufing`")
        return self.data.open[idx+1] < self.data.close[idx] if self._isBulluish(idx) \
            else self.data.open[idx+1] > self.data.close[idx]

    def notify_order(self, order):
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'BUY EXECUTED, {order.executed.price:.2f}')
            elif order.issell():
                self.log(f'SELL EXECUTED, {order.executed.price:.2f}')
        self.order = None
    
    def log(self, txt):
        dt = self.data.datetime.date(0)
        print(f'{dt.isoformat()} {txt}')
    
    def _calculate_size(self, price, sl_price):
        # Calculate the size of the position based on the risk percentage and stop loss
        size = (self.broker.getvalue() * self.params.risk) / abs(price - sl_price)
        return size
    
    def _update_pivots(self):
        if np.max(self.data.high.get(size=self.params.pivot_window * 2 + 1)) == self.data.high[self.params.pivot_window]:
            self.prev_pivot_high = self.data.high[self.params.pivot_window]   
        if np.min(self.data.low.get(size=self.params.pivot_window * 2 + 1)) == self.data.low[self.params.pivot_window]:
            self.prev_pivot_low = self.data.low[self.params.pivot_window]      

    def next(self):
        # if not in a market position, check for crossover from below
        if self.position:
            return
        if self.crossover[0] > 0 and (self._isEngulfing(0) or self._isEngulfing(1)):
            price = self.data.close[0]
            # sl_price = self.data.low[1]
            # sl_price = price * (1 - self.params.stop_loss)
            # sl_price = price - self.params.sl_pips * self.params.pip_value
            sl_price = price - self.atr * self.params.atr_multiplier
            tp_price = price + np.abs(sl_price - price) * self.params.rrr
            if tp_price < price or tp_price < 0:
                self.log(f'Take profit price {tp_price:.2f} is less than entry price {price:.2f}, not placing order.')
                return
            if sl_price > price or sl_price < 0:
                self.log(f'Stop loss price {sl_price:.2f} is greater than entry price {price:.2f}, not placing order.')
                return

            # size = self._calculate_size(price, sl_price)
            self.order = self.buy_bracket(
                exectype=bt.Order.Market, 
                # size=size,
                price=price,
                stopprice=sl_price,
                limitprice=tp_price,
                stopargs=dict(exectype=bt.Order.Stop),
                limitargs=dict(exectype=bt.Order.Limit),
                # trailpercent=self.params.trailpercent
            )
            self.log(f"Bracket order placed: Entry {price:.2f}, SL {sl_price:.2f}, TP {tp_price:.2f}")

        # if in a position, check for crossover from above for exit
        elif self.crossover[0] < 0 and (self._isEngulfing(0) or self._isEngulfing(1)):
            price = self.data.close[0]
            # sl_price = self.data.high[1]
            # sl_price = price * (1 + self.params.stop_loss)
            # sl_price = price + self.params.sl_pips * self.params.pip_value
            sl_price = price + self.atr * self.params.atr_multiplier
            tp_price = price - np.abs(sl_price - price) * self.params.rrr
            if tp_price > price or tp_price < 0:
                self.log(f'Take profit price {tp_price:.2f} is greater than entry price {price:.2f}, not placing order.')
                return
            if sl_price < price or sl_price < 0:
                self.log(f'Stop loss price {sl_price:.2f} is less than entry price {price:.2f}, not placing order.')
                return
            # size = self._calculate_size(price, sl_price)
            self.order = self.sell_bracket(
                exectype=bt.Order.Market, 
                # size=size,
                price=price,
                stopprice=sl_price,
                limitprice=tp_price,
                stopargs=dict(exectype=bt.Order.Stop),
                limitargs=dict(exectype=bt.Order.Limit),
                # trailpercent=self.params.trailpercent
            )
            self.log(f"Bracket order placed: Entry {price:.2f}, SL {sl_price:.2f}, TP {tp_price:.2f}")

# %% [markdown]
# ## Download Data from YF

# %%
# Download SPX500 data from Yahoo Finance
yf_params = {'start': '2018-01-01', 'end': '2024-01-01', 'interval': '1d', 'multi_level_index': False}
# data = yf.download(tickers="^GSPC", **yf_params)
data = yf.download(tickers="DJIA", **yf_params)
# data = yf.download(tickers="^VIX", **yf_params)
# data = yf.download(tickers="^RUT", **yf_params)
# data = yf.download(tickers="^IXIC", **yf_params)
# data = yf.download(tickers="GOOG", **yf_params)
# data = yf.download(tickers="AAPL", **yf_params)
# data = yf.download(tickers="MSFT", **yf_params)
# data = yf.download(tickers="AMZN", **yf_params)
# data = yf.download(tickers="TSLA", **yf_params)
# data = yf.download(tickers="META", **yf_params)
# data = yf.download(tickers="NFLX", **yf_params)
# data = yf.download(tickers="NVDA", **yf_params)
# data = yf.download(tickers="AMD", **yf_params)
data.reset_index(inplace=True)
data['Date'] = pd.to_datetime(data['Date'])
# data.set_index('Date', inplace=True)

# data
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DJIA']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')

# %% [markdown]
# ## Source data locally

# %%
data_local = pd.read_csv("../data/xauusd_1h.csv", index_col=None)
data_local['datetime'] = pd.to_datetime(data_local['datetime'])
print(data_local.head())

data_feed_local = bt.feeds.PandasData(dataname=data_local, name="xau",
                                      datetime=0, openinterest=-1,
                                      open=1,
                                      high=2,
                                      low=3,
                                      close=4,
                                      volume=5)
# Out:
#              datetime         open         high          low        close  \
# 0 2010-01-03 22:00:00  1097.880005  1097.880005  1097.449951  1097.449951
# 1 2010-01-03 23:00:00  1097.680054  1100.599976  1095.979980  1095.979980
# 2 2010-01-04 00:00:00  1096.010010  1096.869995  1093.449951  1094.839966
# 3 2010-01-04 01:00:00  1094.869995  1095.959961  1094.239990  1095.699951
# 4 2010-01-04 02:00:00  1095.670044  1099.150024  1095.630005  1098.329956
#
#    volume
# 0       2
# 1     919
# 2    1596
# 3     869
# 4    1054

# %%
cerebro = bt.Cerebro()
# cerebro.optstrategy(VWAPStrategy, 
#                     ema_period=range(30, 50, 5),
#                     sl_pips=range(50,600, 50),
#                     pip_value=100.0,
#                     rrr=np.arange(1.0, 2.0, .2)
#                     )

cerebro.addstrategy(VWAPStrategy, 
                    ema_period=50,
                    atr_period=21,
                    atr_multiplier=1.5,
                    sl_pips=200,
                    pip_value=.10,
                    rrr=2,
                    )


cerebro.broker.setcash(100_000.0)
cerebro.broker.setcommission(commission=0.001)
data_feed = bt.feeds.pandafeed.PandasData(
    dataname=data,
    datetime=0,
    openinterest=-1,
    open=1,
    high=2,
    low=3,
    close=4,
    volume=5,
)
cerebro.adddata(data_feed_local)

# %%
cerebro.addsizer(bt.sizers.PercentSizer, percents=5)
cerebro.addanalyzer(bt.analyzers.SharpeRatio, riskfreerate=0.01)
cerebro.addanalyzer(bt.analyzers.DrawDown)
cerebro.addanalyzer(bt.analyzers.TradeAnalyzer)
cerebro.addanalyzer(bt.analyzers.Returns)

results = cerebro.run()
# Out:
# 2010-01-08 Bracket order placed: Entry 1137.89, SL 1132.11, TP 1149.45
# 2010-01-08 BUY EXECUTED, 1138.00
# 2010-01-08 SELL EXECUTED, 1132.11
# 2010-01-08 Bracket order placed: Entry 1127.60, SL 1133.95, TP 1114.90
# 2010-01-08 SELL EXECUTED, 1127.64
# 2010-01-08 BUY EXECUTED, 1133.95
# 2010-01-12 Bracket order placed: Entry 1147.84, SL 1153.30, TP 1136.91
# 2010-01-12 SELL EXECUTED, 1147.89
# 2010-01-12 BUY EXECUTED, 1153.30
# 2010-01-12 Bracket order placed: Entry 1147.14, SL 1153.10, TP 1135.23
# 2010-01-12 SELL EXECUTED, 1147.07
# 2010-01-12 BUY EXECUTED, 1135.23
# 2010-01-13 Bracket order placed: Entry 1137.59, SL 1130.39, TP 1152.00
# 2010-01-13 BUY EXECUTED, 1137.56
# 2010-01-15 SELL EXECUTED, 1130.39
# 2010-01-18 Bracket order placed: Entry 1135.92, SL 1131.07, TP 1145.62
# 2010-01-18 BUY EXECUTED, 1135.85
# 2010-01-19 SELL EXECUTED, 1131.07
# 2010-01-19 Bracket order placed: Entry 1139.74, SL 1134.81, TP 1149.62
# 2010-01-19 BUY EXECUTED, 1139.71
# 2010-01-20 SELL EXECUTED, 1134.81
# 2010-01-25 Bracket order placed: Entry 1100.96, SL 1095.09, TP 1112.71
# 2010-01-25 BUY EXECUTED, 1100.94
# 2010-01-25 SELL EXECUTED, 1095.09
# 2010-01-25 Bracket order placed: Entry 1101.09, SL 1095.79, TP 1111.69
# 2010-01-26 BUY EXECUTED, 1101.03
# 2010-01-26 SELL EXECUTED, 1095.79
# 2010-01-27 Bracket order placed: Entry 1097.28, SL 1102.29, TP 1087.25
# 2010-01-27 SELL EXECUTED, 1097.30
# 2010-01-27 BUY EXECUTED, 1087.25
# 2010-02-01 Bracket order placed: Entry 1087.12, SL 1081.52, TP 1098.32
# 2010-02-01 BUY EXECUTED, 1087.07
# 2010-02-01 SELL EXECUTED, 1098.32
# 2010-05-17 Bracket order placed: Entry 1230.73, SL 1239.09, TP 1214.01
# 2010-05-17 SELL EXECUTED, 1230.68
# 2010-05-18 BUY EXECUTED, 1214.01
# 2010-05-18 Bracket order placed: Entry 1227.70, SL 1220.03, TP 1243.06
# 2010-05-18 BUY EXECUTED, 1227.76
# 2010-05-18 SELL EXECUTED, 1220.03
# 2010-05-18 Bracket order placed: Entry 1224.98, SL 1217.04, TP 1240.86
# 2010-05-18 BUY EXECUTED, 1225.03
# 2010-05-19 SELL EXECUTED, 1217.04
# 2010-05-24 Bracket order placed: Entry 1185.11, SL 1176.97, TP 1201.39
# 2010-05-24 BUY EXECUTED, 1185.16
# 2010-05-25 SELL EXECUTED, 1201.39
# 2010-05-28 Bracket order placed: Entry 1209.32, SL 1213.91, TP 1200.14
# 2010-05-28 SELL EXECUTED, 1209.27
# 2010-05-28 BUY EXECUTED, 1213.91
# 2010-05-28 Bracket order placed: Entry 1205.88, SL 1210.41, TP 1196.83
# 2010-05-28 SELL EXECUTED, 1205.93
# 2010-05-28 BUY EXECUTED, 1210.41
# 2010-05-31 Bracket order placed: Entry 1210.97, SL 1206.20, TP 1220.51
# 2010-05-31 BUY EXECUTED, 1210.94
# 2010-06-01 SELL EXECUTED, 1220.51
# 2010-06-02 Bracket order placed: Entry 1219.99, SL 1223.87, TP 1212.25
# 2010-06-02 SELL EXECUTED, 1220.05
# 2010-06-02 BUY EXECUTED, 1223.87
# 2010-06-02 Bracket order placed: Entry 1223.70, SL 1218.89, TP 1233.33
# 2010-06-02 BUY EXECUTED, 1223.64
# 2010-06-03 SELL EXECUTED, 1218.89
# 2010-06-03 Bracket order placed: Entry 1218.61, SL 1222.52, TP 1210.81
# 2010-06-03 SELL EXECUTED, 1218.57
# 2010-06-03 BUY EXECUTED, 1210.81
# 2010-06-04 Bracket order placed: Entry 1212.95, SL 1205.80, TP 1227.26
# 2010-06-04 BUY EXECUTED, 1212.93
# 2010-06-07 SELL EXECUTED, 1227.26
# 2010-06-09 Bracket order placed: Entry 1235.56, SL 1229.60, TP 1247.47
# 2010-06-09 BUY EXECUTED, 1235.60
# 2010-06-09 SELL EXECUTED, 1229.60
# 2010-06-11 Bracket order placed: Entry 1227.95, SL 1222.75, TP 1238.34
# 2010-06-11 BUY EXECUTED, 1227.92
# 2010-06-11 SELL EXECUTED, 1220.46
# 2010-06-11 Bracket order placed: Entry 1224.42, SL 1218.79, TP 1235.69
# 2010-06-11 BUY EXECUTED, 1224.37
# 2010-06-14 SELL EXECUTED, 1218.79
# 2010-06-15 Bracket order placed: Entry 1224.61, SL 1220.42, TP 1232.99
# 2010-06-15 BUY EXECUTED, 1224.56
# 2010-06-15 SELL EXECUTED, 1232.99
# 2010-06-16 Bracket order placed: Entry 1229.27, SL 1234.09, TP 1219.64
# 2010-06-16 SELL EXECUTED, 1229.31
# 2010-06-17 BUY EXECUTED, 1234.09
# 2010-06-17 Bracket order placed: Entry 1231.14, SL 1235.09, TP 1223.23
# 2010-06-17 SELL EXECUTED, 1231.19
# 2010-06-17 BUY EXECUTED, 1235.09
# 2010-06-21 Bracket order placed: Entry 1241.92, SL 1247.83, TP 1230.10
# 2010-06-21 SELL EXECUTED, 1242.02
# 2010-06-23 BUY EXECUTED, 1230.10
# 2010-06-24 Bracket order placed: Entry 1242.63, SL 1236.72, TP 1254.45
# 2010-06-24 BUY EXECUTED, 1242.68
# 2010-06-25 SELL EXECUTED, 1254.45
# 2010-06-28 Bracket order placed: Entry 1248.03, SL 1253.73, TP 1236.63
# 2010-06-28 SELL EXECUTED, 1248.06
# 2010-06-28 BUY EXECUTED, 1236.63
# 2010-06-29 Bracket order placed: Entry 1242.26, SL 1248.96, TP 1228.86
# 2010-06-29 SELL EXECUTED, 1242.21
# 2010-07-01 BUY EXECUTED, 1228.86
# 2010-07-06 Bracket order placed: Entry 1211.81, SL 1207.69, TP 1220.04
# 2010-07-06 BUY EXECUTED, 1211.86
# 2010-07-06 SELL EXECUTED, 1207.69
# 2010-07-08 Bracket order placed: Entry 1199.22, SL 1203.77, TP 1190.11
# 2010-07-08 SELL EXECUTED, 1199.27
# 2010-07-08 BUY EXECUTED, 1190.11
# 2010-07-09 Bracket order placed: Entry 1199.36, SL 1194.12, TP 1209.86
# 2010-07-09 BUY EXECUTED, 1199.30
# 2010-07-09 SELL EXECUTED, 1209.86
# 2010-07-12 Bracket order placed: Entry 1206.84, SL 1202.23, TP 1216.06
# 2010-07-12 BUY EXECUTED, 1206.94
# 2010-07-12 SELL EXECUTED, 1202.23
# 2010-07-12 Bracket order placed: Entry 1199.24, SL 1204.41, TP 1188.90
# 2010-07-12 SELL EXECUTED, 1199.29
# 2010-07-13 BUY EXECUTED, 1204.41
# 2010-07-13 Bracket order placed: Entry 1203.21, SL 1198.93, TP 1211.77
# 2010-07-13 BUY EXECUTED, 1203.14
# 2010-07-13 SELL EXECUTED, 1211.77
# 2010-07-14 Bracket order placed: Entry 1204.29, SL 1209.37, TP 1194.14
# 2010-07-14 SELL EXECUTED, 1204.34
# 2010-07-14 BUY EXECUTED, 1209.37
# 2010-07-14 Bracket order placed: Entry 1209.33, SL 1204.67, TP 1218.66
# 2010-07-14 BUY EXECUTED, 1209.36
# 2010-07-15 SELL EXECUTED, 1204.67
# 2010-07-15 Bracket order placed: Entry 1210.67, SL 1205.23, TP 1221.53
# 2010-07-15 BUY EXECUTED, 1210.71
# 2010-07-16 SELL EXECUTED, 1205.23
# 2010-07-20 Bracket order placed: Entry 1190.63, SL 1185.77, TP 1200.35
# 2010-07-20 BUY EXECUTED, 1190.58
# 2010-07-21 SELL EXECUTED, 1185.77
# 2010-07-21 Bracket order placed: Entry 1184.84, SL 1189.92, TP 1174.68
# 2010-07-21 SELL EXECUTED, 1184.87
# 2010-07-22 BUY EXECUTED, 1189.92
# 2010-07-22 Bracket order placed: Entry 1199.73, SL 1194.53, TP 1210.13
# 2010-07-22 BUY EXECUTED, 1199.86
# 2010-07-23 SELL EXECUTED, 1194.53
# 2010-07-23 Bracket order placed: Entry 1191.79, SL 1196.58, TP 1182.21
# 2010-07-23 SELL EXECUTED, 1191.85
# 2010-07-26 BUY EXECUTED, 1182.21
# 2010-07-29 Bracket order placed: Entry 1168.78, SL 1165.33, TP 1175.67
# 2010-07-29 BUY EXECUTED, 1168.74
# 2010-07-29 SELL EXECUTED, 1165.33
# 2010-07-29 Bracket order placed: Entry 1166.98, SL 1162.36, TP 1176.22
# 2010-07-29 BUY EXECUTED, 1167.01
# 2010-07-30 SELL EXECUTED, 1176.22
# 2010-08-09 Bracket order placed: Entry 1202.05, SL 1205.77, TP 1194.61
# 2010-08-09 SELL EXECUTED, 1202.12
# 2010-08-10 BUY EXECUTED, 1194.61
# 2010-08-11 Bracket order placed: Entry 1200.90, SL 1204.58, TP 1193.55
# 2010-08-11 SELL EXECUTED, 1200.94
# 2010-08-11 BUY EXECUTED, 1204.58
# 2010-08-11 Bracket order placed: Entry 1196.16, SL 1201.32, TP 1185.84
# 2010-08-11 SELL EXECUTED, 1196.13
# 2010-08-11 BUY EXECUTED, 1201.32
# 2010-08-11 Bracket order placed: Entry 1200.62, SL 1195.43, TP 1211.00
# 2010-08-11 BUY EXECUTED, 1200.57
# 2010-08-12 SELL EXECUTED, 1211.00
# 2010-08-18 Bracket order placed: Entry 1221.96, SL 1224.40, TP 1217.09
# 2010-08-18 SELL EXECUTED, 1221.99
# 2010-08-18 BUY EXECUTED, 1224.40
# 2010-08-18 Bracket order placed: Entry 1223.88, SL 1221.39, TP 1228.84
# 2010-08-18 BUY EXECUTED, 1223.92
# 2010-08-18 SELL EXECUTED, 1221.39
# 2010-08-18 Bracket order placed: Entry 1219.45, SL 1222.48, TP 1213.41
# 2010-08-18 SELL EXECUTED, 1219.42
# 2010-08-18 BUY EXECUTED, 1222.48
# 2010-08-22 Bracket order placed: Entry 1228.90, SL 1225.93, TP 1234.84
# 2010-08-22 BUY EXECUTED, 1228.85
# 2010-08-23 SELL EXECUTED, 1225.93
# 2010-08-24 Bracket order placed: Entry 1225.52, SL 1221.06, TP 1234.43
# 2010-08-24 BUY EXECUTED, 1225.49
# 2010-08-25 SELL EXECUTED, 1234.43
# 2010-08-26 Bracket order placed: Entry 1236.06, SL 1239.89, TP 1228.41
# 2010-08-26 SELL EXECUTED, 1236.06
# 2010-08-27 BUY EXECUTED, 1239.89
# 2010-08-27 Bracket order placed: Entry 1235.80, SL 1240.27, TP 1226.86
# 2010-08-27 SELL EXECUTED, 1235.83
# 2010-08-31 BUY EXECUTED, 1240.27
# 2010-09-01 Bracket order placed: Entry 1245.15, SL 1241.24, TP 1252.98
# 2010-09-01 BUY EXECUTED, 1245.20
# 2010-09-02 SELL EXECUTED, 1252.98
# 2010-09-03 Bracket order placed: Entry 1240.06, SL 1243.72, TP 1232.75
# 2010-09-03 SELL EXECUTED, 1240.11
# 2010-09-03 BUY EXECUTED, 1243.72
# 2010-09-03 Bracket order placed: Entry 1248.06, SL 1252.20, TP 1239.78
# 2010-09-03 SELL EXECUTED, 1248.11
# 2010-09-07 BUY EXECUTED, 1252.20
# 2010-09-07 Bracket order placed: Entry 1257.42, SL 1254.33, TP 1263.59
# 2010-09-07 BUY EXECUTED, 1257.45
# 2010-09-08 SELL EXECUTED, 1254.33
# 2010-12-10 Bracket order placed: Entry 1391.19, SL 1385.48, TP 1402.63
# 2010-12-10 BUY EXECUTED, 1391.17
# 2010-12-10 SELL EXECUTED, 1385.48
# 2010-12-14 Bracket order placed: Entry 1395.09, SL 1401.57, TP 1382.12
# 2010-12-14 SELL EXECUTED, 1395.13
# 2010-12-15 BUY EXECUTED, 1382.12
# 2010-12-17 Bracket order placed: Entry 1377.42, SL 1371.05, TP 1390.15
# 2010-12-17 BUY EXECUTED, 1377.39
# 2010-12-21 SELL EXECUTED, 1390.15
# 2010-12-22 Bracket order placed: Entry 1385.48, SL 1389.26, TP 1377.92
# 2010-12-22 SELL EXECUTED, 1385.45
# 2010-12-23 BUY EXECUTED, 1377.92
# 2010-12-24 Bracket order placed: Entry 1382.88, SL 1386.59, TP 1375.47
# 2010-12-24 SELL EXECUTED, 1382.63
# 2010-12-26 BUY EXECUTED, 1375.47
# 2010-12-27 Bracket order placed: Entry 1382.37, SL 1385.76, TP 1375.60
# 2010-12-27 SELL EXECUTED, 1382.42
# 2010-12-28 BUY EXECUTED, 1385.76
# 2010-12-30 Bracket order placed: Entry 1406.33, SL 1410.20, TP 1398.61
# 2010-12-30 SELL EXECUTED, 1406.36
# 2010-12-31 BUY EXECUTED, 1410.20
# 2011-01-03 Bracket order placed: Entry 1414.19, SL 1418.75, TP 1405.09
# 2011-01-03 SELL EXECUTED, 1414.17
# 2011-01-04 BUY EXECUTED, 1405.09
# 2011-01-07 Bracket order placed: Entry 1377.39, SL 1370.49, TP 1391.18
# 2011-01-07 BUY EXECUTED, 1377.35
# 2011-01-07 SELL EXECUTED, 1370.49
# 2011-01-10 Bracket order placed: Entry 1373.56, SL 1367.80, TP 1385.08
# 2011-01-10 BUY EXECUTED, 1373.60
# 2011-01-10 SELL EXECUTED, 1367.80
# 2011-01-10 Bracket order placed: Entry 1367.19, SL 1372.96, TP 1355.63
# 2011-01-10 SELL EXECUTED, 1367.16
# 2011-01-10 BUY EXECUTED, 1372.96
# 2011-01-10 Bracket order placed: Entry 1371.40, SL 1377.51, TP 1359.17
# 2011-01-10 SELL EXECUTED, 1371.43
# 2011-01-11 BUY EXECUTED, 1377.51
# 2011-01-11 Bracket order placed: Entry 1374.82, SL 1380.24, TP 1363.99
# 2011-01-11 SELL EXECUTED, 1374.85
# 2011-01-11 BUY EXECUTED, 1380.24
# 2011-01-12 Bracket order placed: Entry 1381.01, SL 1376.46, TP 1390.09
# 2011-01-12 BUY EXECUTED, 1381.04
# 2011-01-13 SELL EXECUTED, 1390.09
# 2011-01-13 Bracket order placed: Entry 1381.20, SL 1386.54, TP 1370.51
# 2011-01-13 SELL EXECUTED, 1381.23
# 2011-01-13 BUY EXECUTED, 1386.54
# 2011-01-13 Bracket order placed: Entry 1377.83, SL 1383.76, TP 1365.96
# 2011-01-13 SELL EXECUTED, 1377.81
# 2011-01-14 BUY EXECUTED, 1365.96
# 2011-01-18 Bracket order placed: Entry 1366.10, SL 1362.57, TP 1373.18
# 2011-01-18 BUY EXECUTED, 1366.07
# 2011-01-18 SELL EXECUTED, 1373.18
# 2011-04-25 SELL EXECUTED, 1505.73
# 2011-04-26 Bracket order placed: Entry 1506.24, SL 1500.75, TP 1517.24
# 2011-04-26 BUY EXECUTED, 1506.27
# 2011-04-27 SELL EXECUTED, 1517.24
# 2011-05-02 Bracket order placed: Entry 1550.06, SL 1543.36, TP 1563.47
# 2011-05-02 BUY EXECUTED, 1550.04
# 2011-05-02 SELL EXECUTED, 1563.47
# 2011-05-02 Bracket order placed: Entry 1543.10, SL 1552.52, TP 1524.27
# 2011-05-02 SELL EXECUTED, 1543.06
# 2011-05-04 BUY EXECUTED, 1524.27
# 2011-05-09 Bracket order placed: Entry 1497.73, SL 1493.62, TP 1505.95
# 2011-05-09 BUY EXECUTED, 1497.71
# 2011-05-09 SELL EXECUTED, 1505.95
# 2011-05-11 Bracket order placed: Entry 1513.11, SL 1519.10, TP 1501.12
# 2011-05-11 SELL EXECUTED, 1513.13
# 2011-05-11 BUY EXECUTED, 1501.12
# 2011-05-12 Bracket order placed: Entry 1507.32, SL 1497.67, TP 1526.64
# 2011-05-12 BUY EXECUTED, 1507.35
# 2011-05-13 SELL EXECUTED, 1497.67
# 2011-05-16 Bracket order placed: Entry 1496.91, SL 1493.04, TP 1504.66
# 2011-05-16 BUY EXECUTED, 1496.88
# 2011-05-16 SELL EXECUTED, 1493.04
# 2011-05-16 Bracket order placed: Entry 1498.98, SL 1494.06, TP 1508.84
# 2011-05-16 BUY EXECUTED, 1499.01
# 2011-05-16 SELL EXECUTED, 1494.06
# 2011-05-17 Bracket order placed: Entry 1495.20, SL 1490.60, TP 1504.38
# 2011-05-17 BUY EXECUTED, 1495.22
# 2011-05-17 SELL EXECUTED, 1490.60
# 2011-05-18 Bracket order placed: Entry 1490.19, SL 1484.02, TP 1502.51
# 2011-05-18 BUY EXECUTED, 1490.16
# 2011-05-20 SELL EXECUTED, 1502.51
# 2011-05-20 Bracket order placed: Entry 1490.42, SL 1496.82, TP 1477.62
# 2011-05-20 SELL EXECUTED, 1490.44
# 2011-05-20 BUY EXECUTED, 1498.91
# 2011-05-23 Bracket order placed: Entry 1508.27, SL 1511.86, TP 1501.08
# 2011-05-23 SELL EXECUTED, 1508.29
# 2011-05-23 BUY EXECUTED, 1511.86
# 2011-05-26 Bracket order placed: Entry 1522.08, SL 1526.17, TP 1513.91
# 2011-05-26 SELL EXECUTED, 1522.05
# 2011-05-26 BUY EXECUTED, 1526.17
# 2011-05-26 Bracket order placed: Entry 1525.81, SL 1520.95, TP 1535.52
# 2011-05-26 BUY EXECUTED, 1525.83
# 2011-05-26 SELL EXECUTED, 1516.28
# 2011-05-31 Bracket order placed: Entry 1536.07, SL 1538.75, TP 1530.72
# 2011-05-31 SELL EXECUTED, 1536.05
# 2011-05-31 BUY EXECUTED, 1538.75
# 2011-05-31 Bracket order placed: Entry 1536.21, SL 1539.57, TP 1529.49
# 2011-05-31 SELL EXECUTED, 1536.18
# 2011-06-01 BUY EXECUTED, 1539.57
# 2011-06-03 Bracket order placed: Entry 1542.03, SL 1535.12, TP 1555.85
# 2011-06-03 BUY EXECUTED, 1542.07
# 2011-07-12 SELL EXECUTED, 1559.48
# 2011-07-15 Bracket order placed: Entry 1582.43, SL 1576.53, TP 1594.22
# 2011-07-15 BUY EXECUTED, 1582.46
# 2011-07-17 SELL EXECUTED, 1594.22
# 2011-07-20 Bracket order placed: Entry 1597.27, SL 1590.91, TP 1610.00
# 2011-07-20 BUY EXECUTED, 1597.25
# 2011-07-21 SELL EXECUTED, 1590.91
# 2011-07-21 Bracket order placed: Entry 1594.59, SL 1601.38, TP 1581.02
# 2011-07-21 SELL EXECUTED, 1594.57
# 2011-07-22 BUY EXECUTED, 1601.38
# 2011-07-26 Bracket order placed: Entry 1609.93, SL 1614.42, TP 1600.94
# 2011-07-26 SELL EXECUTED, 1609.95
# 2011-07-26 BUY EXECUTED, 1614.42
# 2011-07-26 Bracket order placed: Entry 1613.60, SL 1608.67, TP 1623.45
# 2011-07-26 BUY EXECUTED, 1613.57
# 2011-07-27 SELL EXECUTED, 1623.45
# 2011-07-27 Bracket order placed: Entry 1613.40, SL 1619.59, TP 1601.01
# 2011-07-27 SELL EXECUTED, 1613.37
# 2011-07-28 BUY EXECUTED, 1619.59
# 2011-07-28 Bracket order placed: Entry 1618.54, SL 1613.54, TP 1628.55
# 2011-07-28 BUY EXECUTED, 1618.51
# 2011-07-28 SELL EXECUTED, 1613.54
# 2011-07-28 Bracket order placed: Entry 1614.19, SL 1619.08, TP 1604.40
# 2011-07-28 SELL EXECUTED, 1614.21
# 2011-07-28 BUY EXECUTED, 1619.08
# 2011-07-28 Bracket order placed: Entry 1616.05, SL 1609.92, TP 1628.32
# 2011-07-28 BUY EXECUTED, 1615.97
# 2011-07-29 SELL EXECUTED, 1628.32
# 2011-08-02 Bracket order placed: Entry 1621.14, SL 1616.13, TP 1631.16
# 2011-08-02 BUY EXECUTED, 1621.17
# 2011-08-02 SELL EXECUTED, 1631.16
# 2011-08-05 Bracket order placed: Entry 1657.71, SL 1647.34, TP 1678.44
# 2011-08-05 BUY EXECUTED, 1657.69
# 2011-08-07 SELL EXECUTED, 1678.44
# 2011-08-11 Bracket order placed: Entry 1760.29, SL 1781.33, TP 1718.22
# 2011-08-11 SELL EXECUTED, 1760.50
# 2011-08-16 BUY EXECUTED, 1781.33
# 2011-08-23 Bracket order placed: Entry 1874.73, SL 1887.90, TP 1848.39
# 2011-08-23 SELL EXECUTED, 1874.69
# 2011-08-23 BUY EXECUTED, 1887.90
# 2011-08-23 Bracket order placed: Entry 1876.01, SL 1889.72, TP 1848.57
# 2011-08-23 SELL EXECUTED, 1875.95
# 2011-08-23 BUY EXECUTED, 1848.57
# 2011-08-26 Bracket order placed: Entry 1774.70, SL 1793.19, TP 1737.73
# 2011-08-26 SELL EXECUTED, 1774.67
# 2011-08-26 BUY EXECUTED, 1793.19
# 2011-08-29 Bracket order placed: Entry 1810.99, SL 1818.84, TP 1795.29
# 2011-08-29 SELL EXECUTED, 1811.04
# 2011-08-29 BUY EXECUTED, 1818.84
# 2011-08-29 Bracket order placed: Entry 1819.05, SL 1810.78, TP 1835.58
# 2011-08-29 BUY EXECUTED, 1819.00
# 2011-08-29 SELL EXECUTED, 1810.78
# 2011-08-30 Bracket order placed: Entry 1812.95, SL 1800.98, TP 1836.90
# 2011-08-30 BUY EXECUTED, 1812.92
# 2011-08-30 SELL EXECUTED, 1836.90
# 2011-08-31 Bracket order placed: Entry 1818.13, SL 1830.58, TP 1793.23
# 2011-08-31 SELL EXECUTED, 1818.17
# 2011-08-31 BUY EXECUTED, 1830.58
# 2011-09-01 Bracket order placed: Entry 1822.06, SL 1832.14, TP 1801.88
# 2011-09-01 SELL EXECUTED, 1822.09
# 2011-09-02 BUY EXECUTED, 1832.14
# 2011-09-06 Bracket order placed: Entry 1884.26, SL 1894.37, TP 1864.03
# 2011-09-06 SELL EXECUTED, 1884.16
# 2011-09-06 BUY EXECUTED, 1894.37
# 2011-09-06 Bracket order placed: Entry 1888.22, SL 1902.35, TP 1859.94
# 2011-09-06 SELL EXECUTED, 1888.25
# 2011-09-06 BUY EXECUTED, 1902.35
# 2011-09-06 Bracket order placed: Entry 1870.14, SL 1887.81, TP 1834.79
# 2011-09-06 SELL EXECUTED, 1870.05
# 2011-09-06 BUY EXECUTED, 1887.81
# 2011-09-09 Bracket order placed: Entry 1831.49, SL 1848.97, TP 1796.53
# 2011-09-09 SELL EXECUTED, 1831.45
# 2011-09-09 BUY EXECUTED, 1848.97
# 2011-09-09 Bracket order placed: Entry 1858.96, SL 1840.00, TP 1896.88
# 2011-09-09 BUY EXECUTED, 1858.92
# 2011-09-12 SELL EXECUTED, 1840.00
# 2011-09-13 Bracket order placed: Entry 1839.43, SL 1824.04, TP 1870.21
# 2011-09-13 BUY EXECUTED, 1839.40
# 2011-09-14 SELL EXECUTED, 1824.04
# 2011-09-14 Bracket order placed: Entry 1833.21, SL 1820.20, TP 1859.23
# 2011-09-14 BUY EXECUTED, 1833.15
# 2011-09-14 SELL EXECUTED, 1820.20
# 2011-09-19 Bracket order placed: Entry 1796.87, SL 1806.97, TP 1776.66
# 2011-09-19 SELL EXECUTED, 1796.84
# 2011-09-19 BUY EXECUTED, 1776.66
# 2011-09-20 Bracket order placed: Entry 1805.91, SL 1792.88, TP 1831.95
# 2011-09-20 BUY EXECUTED, 1805.88
# 2011-09-21 SELL EXECUTED, 1792.88
# 2011-09-21 Bracket order placed: Entry 1802.10, SL 1790.22, TP 1825.85
# 2011-09-21 BUY EXECUTED, 1802.14
# 2011-09-21 SELL EXECUTED, 1790.22
# 2011-09-21 Bracket order placed: Entry 1792.11, SL 1806.28, TP 1763.77
# 2011-09-21 SELL EXECUTED, 1792.15
# 2011-09-22 BUY EXECUTED, 1763.77
# 2011-09-27 Bracket order placed: Entry 1637.51, SL 1661.34, TP 1589.85
# 2011-09-27 SELL EXECUTED, 1637.47
# 2011-09-27 BUY EXECUTED, 1661.34
# 2011-09-27 Bracket order placed: Entry 1646.72, SL 1668.96, TP 1602.24
# 2011-09-27 SELL EXECUTED, 1646.68
# 2011-09-28 BUY EXECUTED, 1668.96
# 2011-09-28 Bracket order placed: Entry 1648.37, SL 1630.40, TP 1684.31
# 2011-09-28 BUY EXECUTED, 1648.34
# 2011-11-15 SELL EXECUTED, 1773.10
# 2011-11-15 BUY EXECUTED, 1782.71
# 2011-11-15 Bracket order placed: Entry 1778.60, SL 1768.53, TP 1798.75
# 2011-11-16 BUY EXECUTED, 1778.66
# 2011-11-16 SELL EXECUTED, 1768.53
# 2011-11-16 Bracket order placed: Entry 1775.59, SL 1765.81, TP 1795.15
# 2011-11-16 BUY EXECUTED, 1775.55
# 2011-11-16 SELL EXECUTED, 1765.81
# 2011-11-16 Bracket order placed: Entry 1775.72, SL 1764.13, TP 1798.91
# 2011-11-16 BUY EXECUTED, 1775.78
# 2011-11-16 SELL EXECUTED, 1764.13
# 2011-11-22 Bracket order placed: Entry 1702.38, SL 1690.92, TP 1725.29
# 2011-11-22 BUY EXECUTED, 1702.42
# 2011-11-23 SELL EXECUTED, 1690.92
# 2011-11-24 Bracket order placed: Entry 1696.88, SL 1688.53, TP 1713.58
# 2011-11-24 BUY EXECUTED, 1696.92
# 2011-11-25 SELL EXECUTED, 1688.53
# 2011-11-25 Bracket order placed: Entry 1693.11, SL 1684.70, TP 1709.94
# 2011-11-25 BUY EXECUTED, 1693.06
# 2011-11-25 SELL EXECUTED, 1684.70
# 2011-11-27 Bracket order placed: Entry 1693.66, SL 1686.46, TP 1708.05
# 2011-11-28 BUY EXECUTED, 1693.51
# 2011-11-28 SELL EXECUTED, 1708.05
# 2011-11-30 Bracket order placed: Entry 1716.93, SL 1708.29, TP 1734.20
# 2011-11-30 BUY EXECUTED, 1716.87
# 2011-11-30 SELL EXECUTED, 1734.20
# 2011-12-05 Bracket order placed: Entry 1741.72, SL 1748.37, TP 1728.43
# 2011-12-05 SELL EXECUTED, 1741.77
# 2011-12-05 BUY EXECUTED, 1728.43
# 2011-12-07 Bracket order placed: Entry 1727.65, SL 1734.52, TP 1713.92
# 2011-12-07 SELL EXECUTED, 1727.70
# 2011-12-07 BUY EXECUTED, 1734.52
# 2011-12-07 Bracket order placed: Entry 1733.46, SL 1725.55, TP 1749.30
# 2011-12-07 BUY EXECUTED, 1733.35
# 2011-12-08 SELL EXECUTED, 1749.30
# 2011-12-08 Bracket order placed: Entry 1717.13, SL 1726.52, TP 1698.34
# 2011-12-08 SELL EXECUTED, 1717.18
# 2011-12-12 BUY EXECUTED, 1698.34
# 2011-12-16 Bracket order placed: Entry 1593.30, SL 1581.70, TP 1616.49
# 2011-12-16 BUY EXECUTED, 1593.26
# 2011-12-20 SELL EXECUTED, 1616.49
# 2011-12-21 Bracket order placed: Entry 1613.35, SL 1603.88, TP 1632.27
# 2011-12-21 BUY EXECUTED, 1613.39
# 2011-12-22 SELL EXECUTED, 1603.88
# 2011-12-22 Bracket order placed: Entry 1613.91, SL 1605.76, TP 1630.19
# 2011-12-22 BUY EXECUTED, 1613.95
# 2011-12-22 SELL EXECUTED, 1605.76
# 2011-12-22 Bracket order placed: Entry 1606.91, SL 1615.33, TP 1590.06
# 2011-12-22 SELL EXECUTED, 1606.95
# 2011-12-27 BUY EXECUTED, 1590.06
# 2011-12-30 Bracket order placed: Entry 1558.70, SL 1549.41, TP 1577.28
# 2011-12-30 BUY EXECUTED, 1558.64
# 2011-12-30 SELL EXECUTED, 1577.28
# 2012-01-05 Bracket order placed: Entry 1608.31, SL 1598.54, TP 1627.85
# 2012-01-05 BUY EXECUTED, 1608.22
# 2012-01-06 SELL EXECUTED, 1627.85
# 2012-01-09 Bracket order placed: Entry 1617.85, SL 1610.43, TP 1632.69
# 2012-01-09 BUY EXECUTED, 1617.81
# 2012-01-09 SELL EXECUTED, 1610.43
# 2012-01-10 Bracket order placed: Entry 1614.89, SL 1607.63, TP 1629.41
# 2012-01-10 BUY EXECUTED, 1614.85
# 2012-01-10 SELL EXECUTED, 1629.41
# 2012-01-13 Bracket order placed: Entry 1645.25, SL 1638.85, TP 1658.07
# 2012-01-13 BUY EXECUTED, 1645.18
# 2012-01-13 SELL EXECUTED, 1638.85
# 2012-01-16 Bracket order placed: Entry 1642.90, SL 1636.15, TP 1656.39
# 2012-01-16 BUY EXECUTED, 1642.85
# 2012-01-17 SELL EXECUTED, 1656.39
# 2012-01-18 Bracket order placed: Entry 1647.68, SL 1653.98, TP 1635.08
# 2012-01-18 SELL EXECUTED, 1647.64
# 2012-01-18 BUY EXECUTED, 1653.98
# 2012-01-18 Bracket order placed: Entry 1653.68, SL 1647.38, TP 1666.30
# 2012-01-18 BUY EXECUTED, 1653.64
# 2012-01-18 SELL EXECUTED, 1647.38
# 2012-01-19 Bracket order placed: Entry 1657.80, SL 1664.55, TP 1644.29
# 2012-01-19 SELL EXECUTED, 1657.84
# 2012-01-20 BUY EXECUTED, 1664.55
# 2012-01-25 Bracket order placed: Entry 1666.56, SL 1671.39, TP 1656.91
# 2012-01-25 SELL EXECUTED, 1666.52
# 2012-01-25 BUY EXECUTED, 1656.91
# 2012-01-25 Bracket order placed: Entry 1690.03, SL 1681.51, TP 1707.07
# 2012-01-25 BUY EXECUTED, 1689.98
# 2012-01-25 SELL EXECUTED, 1707.07
# 2012-01-30 Bracket order placed: Entry 1723.36, SL 1716.94, TP 1736.19
# 2012-01-30 BUY EXECUTED, 1723.40
# 2012-01-31 SELL EXECUTED, 1736.19
# 2012-01-31 Bracket order placed: Entry 1729.15, SL 1736.72, TP 1714.03
# 2012-01-31 SELL EXECUTED, 1729.10
# 2012-01-31 BUY EXECUTED, 1736.72
# 2012-01-31 Bracket order placed: Entry 1736.35, SL 1728.56, TP 1751.92
# 2012-01-31 BUY EXECUTED, 1736.30
# 2012-02-02 SELL EXECUTED, 1751.92
# 2012-02-03 Bracket order placed: Entry 1737.36, SL 1744.83, TP 1722.44
# 2012-02-03 SELL EXECUTED, 1737.47
# 2012-02-06 BUY EXECUTED, 1722.44
# 2012-02-08 Bracket order placed: Entry 1733.34, SL 1741.85, TP 1716.34
# 2012-02-08 SELL EXECUTED, 1733.39
# 2012-02-09 BUY EXECUTED, 1741.85
# 2012-02-09 Bracket order placed: Entry 1748.20, SL 1739.81, TP 1765.00
# 2012-02-09 BUY EXECUTED, 1748.25
# 2012-02-09 SELL EXECUTED, 1739.81
# 2012-02-09 Bracket order placed: Entry 1732.64, SL 1741.71, TP 1714.50
# 2012-02-09 SELL EXECUTED, 1732.69
# 2012-02-10 BUY EXECUTED, 1714.50
# 2012-02-13 Bracket order placed: Entry 1728.04, SL 1721.46, TP 1741.20
# 2012-02-13 BUY EXECUTED, 1728.08
# 2012-02-13 SELL EXECUTED, 1721.46
# 2012-02-14 Bracket order placed: Entry 1723.70, SL 1716.54, TP 1738.03
# 2012-02-14 BUY EXECUTED, 1723.77
# 2012-02-14 SELL EXECUTED, 1716.54
# 2012-02-15 Bracket order placed: Entry 1724.63, SL 1731.65, TP 1710.60
# 2012-02-15 SELL EXECUTED, 1724.58
# 2012-02-16 BUY EXECUTED, 1710.60
# 2012-02-16 Bracket order placed: Entry 1724.42, SL 1717.13, TP 1739.00
# 2012-02-16 BUY EXECUTED, 1724.38
# 2012-02-21 SELL EXECUTED, 1739.00
# 2012-02-26 Bracket order placed: Entry 1773.24, SL 1778.68, TP 1762.34
# 2012-02-27 SELL EXECUTED, 1773.17
# 2012-02-27 BUY EXECUTED, 1762.34
# 2012-02-27 Bracket order placed: Entry 1776.76, SL 1770.58, TP 1789.13
# 2012-02-27 BUY EXECUTED, 1776.82
# 2012-02-27 SELL EXECUTED, 1770.58
# 2012-02-28 Bracket order placed: Entry 1772.14, SL 1766.92, TP 1782.58
# 2012-02-28 BUY EXECUTED, 1772.19
# 2012-02-28 SELL EXECUTED, 1782.58
# 2012-02-29 Bracket order placed: Entry 1779.43, SL 1785.18, TP 1767.94
# 2012-02-29 SELL EXECUTED, 1779.38
# 2012-02-29 BUY EXECUTED, 1785.18
# 2012-02-29 Bracket order placed: Entry 1737.71, SL 1748.17, TP 1716.81
# 2012-02-29 SELL EXECUTED, 1737.77
# 2012-02-29 BUY EXECUTED, 1716.81
# 2012-03-08 Bracket order placed: Entry 1685.51, SL 1679.53, TP 1697.46
# 2012-03-08 BUY EXECUTED, 1685.46
# 2012-03-08 SELL EXECUTED, 1697.46
# 2012-03-09 Bracket order placed: Entry 1683.15, SL 1689.89, TP 1669.67
# 2012-03-09 SELL EXECUTED, 1683.19
# 2012-03-09 BUY EXECUTED, 1689.89
# 2012-03-09 Bracket order placed: Entry 1712.25, SL 1703.26, TP 1730.23
# 2012-03-09 BUY EXECUTED, 1712.20
# 2012-03-12 SELL EXECUTED, 1703.26
# 2012-03-13 Bracket order placed: Entry 1702.49, SL 1696.12, TP 1715.22
# 2012-03-13 BUY EXECUTED, 1702.44
# 2012-03-13 SELL EXECUTED, 1696.12
# 2012-03-15 Bracket order placed: Entry 1662.12, SL 1652.41, TP 1681.52
# 2012-03-15 BUY EXECUTED, 1662.16
# 2012-03-16 SELL EXECUTED, 1652.41
# 2012-03-16 Bracket order placed: Entry 1656.95, SL 1648.63, TP 1673.59
# 2012-03-16 BUY EXECUTED, 1656.88
# 2012-03-20 SELL EXECUTED, 1648.63
# 2012-03-21 Bracket order placed: Entry 1655.11, SL 1648.90, TP 1667.53
# 2012-03-21 BUY EXECUTED, 1655.16
# 2012-03-21 SELL EXECUTED, 1648.90
# 2012-03-22 Bracket order placed: Entry 1654.80, SL 1648.70, TP 1666.99
# 2012-03-22 BUY EXECUTED, 1654.84
# 2012-03-22 SELL EXECUTED, 1648.70
# 2012-03-23 Bracket order placed: Entry 1646.26, SL 1652.66, TP 1633.46
# 2012-03-23 SELL EXECUTED, 1646.31
# 2012-03-23 BUY EXECUTED, 1652.66
# 2012-03-23 Bracket order placed: Entry 1653.19, SL 1646.71, TP 1666.16
# 2012-03-23 BUY EXECUTED, 1653.15
# 2012-03-23 SELL EXECUTED, 1666.16
# 2012-03-28 Bracket order placed: Entry 1679.44, SL 1685.17, TP 1667.99
# 2012-03-28 SELL EXECUTED, 1679.40
# 2012-03-28 BUY EXECUTED, 1667.99
# 2012-03-30 Bracket order placed: Entry 1664.81, SL 1659.42, TP 1675.59
# 2012-03-30 BUY EXECUTED, 1664.75
# 2012-04-02 SELL EXECUTED, 1675.59
# 2012-04-06 Bracket order placed: Entry 1633.82, SL 1628.71, TP 1644.05
# 2012-04-06 BUY EXECUTED, 1632.82
# 2012-04-08 SELL EXECUTED, 1644.05
# 2012-04-10 Bracket order placed: Entry 1633.28, SL 1639.59, TP 1620.65
# 2012-04-10 SELL EXECUTED, 1633.23
# 2012-04-10 BUY EXECUTED, 1639.74
# 2012-04-12 Bracket order placed: Entry 1654.89, SL 1659.54, TP 1645.57
# 2012-04-12 SELL EXECUTED, 1654.82
# 2012-04-12 BUY EXECUTED, 1659.54
# 2012-04-13 Bracket order placed: Entry 1666.31, SL 1671.75, TP 1655.42
# 2012-04-13 SELL EXECUTED, 1666.35
# 2012-04-13 BUY EXECUTED, 1655.42
# 2012-04-13 Bracket order placed: Entry 1653.02, SL 1659.84, TP 1639.38
# 2012-04-13 SELL EXECUTED, 1652.97
# 2012-04-17 BUY EXECUTED, 1639.38
# 2012-04-17 Bracket order placed: Entry 1652.97, SL 1645.50, TP 1667.90
# 2012-04-17 BUY EXECUTED, 1652.93
# 2012-04-18 SELL EXECUTED, 1645.50
# 2012-04-19 Bracket order placed: Entry 1639.75, SL 1647.02, TP 1625.21
# 2012-04-19 SELL EXECUTED, 1639.80
# 2012-04-20 BUY EXECUTED, 1647.02
# 2012-04-20 Bracket order placed: Entry 1642.68, SL 1647.88, TP 1632.29
# 2012-04-20 SELL EXECUTED, 1642.73
# 2012-04-23 BUY EXECUTED, 1632.29
# 2012-04-24 Bracket order placed: Entry 1638.70, SL 1634.31, TP 1647.48
# 2012-04-24 BUY EXECUTED, 1638.66
# 2012-04-24 SELL EXECUTED, 1647.48
# 2012-04-25 Bracket order placed: Entry 1637.42, SL 1641.16, TP 1629.95
# 2012-04-25 SELL EXECUTED, 1637.46
# ...
# 2024-02-08 SELL EXECUTED, 2032.86
# 2024-02-08 BUY EXECUTED, 2037.74
# 2024-02-08 Bracket order placed: Entry 2029.11, SL 2034.52, TP 2018.29
# 2024-02-08 SELL EXECUTED, 2029.12
# 2024-02-08 BUY EXECUTED, 2034.52
# 2024-02-09 Bracket order placed: Entry 2032.11, SL 2037.65, TP 2021.04
# 2024-02-09 SELL EXECUTED, 2032.12
# 2024-02-09 BUY EXECUTED, 2021.04
# 2024-02-13 Bracket order placed: Entry 2004.46, SL 2010.31, TP 1992.77
# 2024-02-13 SELL EXECUTED, 2004.45
# 2024-02-13 BUY EXECUTED, 1992.77
# 2024-02-16 Bracket order placed: Entry 2001.52, SL 2006.12, TP 1992.32
# 2024-02-16 SELL EXECUTED, 2001.56
# 2024-02-16 BUY EXECUTED, 2006.12
# 2024-02-21 Bracket order placed: Entry 2022.00, SL 2026.37, TP 2013.27
# 2024-02-21 SELL EXECUTED, 2022.03
# 2024-02-21 BUY EXECUTED, 2026.37
# 2024-02-22 Bracket order placed: Entry 2025.73, SL 2030.16, TP 2016.88
# 2024-02-22 SELL EXECUTED, 2025.73
# 2024-02-23 BUY EXECUTED, 2016.88
# 2024-02-26 Bracket order placed: Entry 2027.61, SL 2032.52, TP 2017.79
# 2024-02-26 SELL EXECUTED, 2027.67
# 2024-02-26 BUY EXECUTED, 2032.52
# 2024-02-27 Bracket order placed: Entry 2032.29, SL 2036.49, TP 2023.90
# 2024-02-27 SELL EXECUTED, 2032.32
# 2024-02-28 BUY EXECUTED, 2036.49
# 2024-02-29 Bracket order placed: Entry 2047.72, SL 2042.75, TP 2057.66
# 2024-02-29 BUY EXECUTED, 2047.71
# 2024-03-01 SELL EXECUTED, 2042.75
# 2024-03-12 Bracket order placed: Entry 2172.00, SL 2178.70, TP 2158.59
# 2024-03-12 SELL EXECUTED, 2171.99
# 2024-03-12 BUY EXECUTED, 2158.59
# 2024-03-13 Bracket order placed: Entry 2166.10, SL 2158.75, TP 2180.82
# 2024-03-13 BUY EXECUTED, 2166.11
# 2024-03-14 SELL EXECUTED, 2158.75
# 2024-03-15 Bracket order placed: Entry 2169.25, SL 2163.55, TP 2180.64
# 2024-03-15 BUY EXECUTED, 2169.28
# 2024-03-15 SELL EXECUTED, 2163.55
# 2024-03-18 Bracket order placed: Entry 2161.15, SL 2155.24, TP 2172.95
# 2024-03-18 BUY EXECUTED, 2161.19
# 2024-03-18 SELL EXECUTED, 2155.24
# 2024-03-19 Bracket order placed: Entry 2157.67, SL 2162.80, TP 2147.41
# 2024-03-19 SELL EXECUTED, 2157.70
# 2024-03-19 BUY EXECUTED, 2147.41
# 2024-03-19 Bracket order placed: Entry 2158.78, SL 2153.25, TP 2169.86
# 2024-03-19 BUY EXECUTED, 2158.77
# 2024-03-20 SELL EXECUTED, 2153.25
# 2024-03-20 Bracket order placed: Entry 2157.99, SL 2152.70, TP 2168.56
# 2024-03-20 BUY EXECUTED, 2157.95
# 2024-03-20 SELL EXECUTED, 2168.56
# 2024-03-21 Bracket order placed: Entry 2176.71, SL 2187.63, TP 2154.87
# 2024-03-21 SELL EXECUTED, 2176.67
# 2024-03-26 BUY EXECUTED, 2187.63
# 2024-03-26 Bracket order placed: Entry 2174.40, SL 2183.45, TP 2156.28
# 2024-03-26 SELL EXECUTED, 2174.38
# 2024-03-27 BUY EXECUTED, 2183.45
# 2024-04-05 Bracket order placed: Entry 2289.24, SL 2278.51, TP 2310.68
# 2024-04-05 BUY EXECUTED, 2289.23
# 2024-04-05 SELL EXECUTED, 2310.68
# 2024-06-07 Bracket order placed: Entry 2347.43, SL 2358.70, TP 2324.88
# 2024-06-07 SELL EXECUTED, 2347.33
# 2024-06-07 BUY EXECUTED, 2324.88
# 2024-06-11 Bracket order placed: Entry 2310.17, SL 2319.13, TP 2292.24
# 2024-06-11 SELL EXECUTED, 2310.36
# 2024-06-12 BUY EXECUTED, 2319.13
# 2024-06-12 Bracket order placed: Entry 2336.02, SL 2327.77, TP 2352.54
# 2024-06-12 BUY EXECUTED, 2335.91
# 2024-06-12 SELL EXECUTED, 2327.77
# 2024-06-13 Bracket order placed: Entry 2312.78, SL 2322.94, TP 2292.46
# 2024-06-13 SELL EXECUTED, 2312.77
# 2024-06-13 BUY EXECUTED, 2322.94
# 2024-06-14 Bracket order placed: Entry 2312.72, SL 2303.91, TP 2330.34
# 2024-06-14 BUY EXECUTED, 2312.72
# 2024-06-14 SELL EXECUTED, 2330.34
# 2024-06-17 Bracket order placed: Entry 2321.38, SL 2313.14, TP 2337.84
# 2024-06-17 BUY EXECUTED, 2321.36
# 2024-06-17 SELL EXECUTED, 2313.14
# 2024-06-17 Bracket order placed: Entry 2320.24, SL 2311.87, TP 2336.99
# 2024-06-17 BUY EXECUTED, 2320.26
# 2024-06-18 SELL EXECUTED, 2311.87
# 2024-06-18 Bracket order placed: Entry 2326.80, SL 2318.25, TP 2343.91
# 2024-06-18 BUY EXECUTED, 2326.78
# 2024-06-20 SELL EXECUTED, 2343.91
# 2024-06-24 Bracket order placed: Entry 2334.43, SL 2326.72, TP 2349.84
# 2024-06-24 BUY EXECUTED, 2333.95
# 2024-06-25 SELL EXECUTED, 2326.72
# 2024-06-25 Bracket order placed: Entry 2333.14, SL 2325.78, TP 2347.84
# 2024-06-25 BUY EXECUTED, 2333.11
# 2024-06-25 SELL EXECUTED, 2325.78
# 2024-07-01 Bracket order placed: Entry 2324.16, SL 2332.88, TP 2306.70
# 2024-07-01 SELL EXECUTED, 2324.16
# 2024-07-02 BUY EXECUTED, 2332.88
# 2024-07-02 Bracket order placed: Entry 2325.02, SL 2332.25, TP 2310.58
# 2024-07-02 SELL EXECUTED, 2325.03
# 2024-07-02 BUY EXECUTED, 2332.25
# 2024-07-02 Bracket order placed: Entry 2326.74, SL 2335.22, TP 2309.76
# 2024-07-02 SELL EXECUTED, 2326.78
# 2024-07-03 BUY EXECUTED, 2335.22
# 2024-07-08 Bracket order placed: Entry 2370.24, SL 2378.31, TP 2354.10
# 2024-07-08 SELL EXECUTED, 2370.07
# 2024-07-08 BUY EXECUTED, 2378.31
# 2024-07-09 Bracket order placed: Entry 2367.75, SL 2359.85, TP 2383.57
# 2024-07-09 BUY EXECUTED, 2367.75
# 2024-07-09 SELL EXECUTED, 2359.85
# 2024-07-09 Bracket order placed: Entry 2367.77, SL 2360.13, TP 2383.06
# 2024-07-09 BUY EXECUTED, 2367.12
# 2024-07-09 SELL EXECUTED, 2355.10
# 2024-07-09 Bracket order placed: Entry 2365.07, SL 2357.29, TP 2380.64
# 2024-07-10 BUY EXECUTED, 2365.09
# 2024-07-10 SELL EXECUTED, 2380.64
# 2024-07-23 Bracket order placed: Entry 2406.93, SL 2397.94, TP 2424.90
# 2024-07-23 BUY EXECUTED, 2406.93
# 2024-07-24 SELL EXECUTED, 2424.90
# 2024-07-24 Bracket order placed: Entry 2409.24, SL 2418.81, TP 2390.08
# 2024-07-24 SELL EXECUTED, 2409.06
# 2024-07-25 BUY EXECUTED, 2390.08
# 2024-07-26 Bracket order placed: Entry 2381.51, SL 2370.76, TP 2403.01
# 2024-07-26 BUY EXECUTED, 2381.91
# 2024-07-28 SELL EXECUTED, 2403.01
# 2024-07-29 Bracket order placed: Entry 2381.30, SL 2391.40, TP 2361.09
# 2024-07-29 SELL EXECUTED, 2381.31
# 2024-07-30 BUY EXECUTED, 2391.40
# 2024-07-30 Bracket order placed: Entry 2385.39, SL 2393.96, TP 2368.24
# 2024-07-30 SELL EXECUTED, 2385.43
# 2024-07-30 BUY EXECUTED, 2400.04
# 2024-08-02 Bracket order placed: Entry 2442.46, SL 2426.72, TP 2473.92
# 2024-08-04 BUY EXECUTED, 2441.94
# 2024-08-05 SELL EXECUTED, 2426.72
# 2024-08-05 Bracket order placed: Entry 2438.09, SL 2455.77, TP 2402.75
# 2024-08-05 SELL EXECUTED, 2438.13
# 2024-08-05 BUY EXECUTED, 2402.75
# 2024-08-08 Bracket order placed: Entry 2397.83, SL 2387.62, TP 2418.26
# 2024-08-08 BUY EXECUTED, 2397.77
# 2024-08-08 SELL EXECUTED, 2418.26
# 2024-08-15 Bracket order placed: Entry 2456.13, SL 2447.55, TP 2473.29
# 2024-08-15 BUY EXECUTED, 2456.07
# 2024-08-15 SELL EXECUTED, 2447.55
# 2024-08-15 Bracket order placed: Entry 2441.25, SL 2450.84, TP 2422.07
# 2024-08-15 SELL EXECUTED, 2441.32
# 2024-08-15 BUY EXECUTED, 2450.84
# 2024-08-15 Bracket order placed: Entry 2458.47, SL 2447.33, TP 2480.76
# 2024-08-15 BUY EXECUTED, 2458.47
# 2024-08-16 SELL EXECUTED, 2480.76
# 2024-08-21 Bracket order placed: Entry 2509.44, SL 2500.42, TP 2527.46
# 2024-08-21 BUY EXECUTED, 2509.48
# 2024-08-21 SELL EXECUTED, 2500.42
# 2024-08-21 Bracket order placed: Entry 2503.14, SL 2512.85, TP 2483.71
# 2024-08-21 SELL EXECUTED, 2503.11
# 2024-08-21 BUY EXECUTED, 2512.85
# 2024-08-22 Bracket order placed: Entry 2507.69, SL 2516.89, TP 2489.29
# 2024-08-22 SELL EXECUTED, 2507.70
# 2024-08-22 BUY EXECUTED, 2489.29
# 2024-08-27 Bracket order placed: Entry 2504.98, SL 2512.91, TP 2489.12
# 2024-08-27 SELL EXECUTED, 2504.92
# 2024-08-27 BUY EXECUTED, 2512.91
# 2024-08-27 Bracket order placed: Entry 2511.53, SL 2503.58, TP 2527.45
# 2024-08-27 BUY EXECUTED, 2511.53
# 2024-08-27 SELL EXECUTED, 2527.45
# 2024-08-28 Bracket order placed: Entry 2511.58, SL 2519.59, TP 2495.57
# 2024-08-28 SELL EXECUTED, 2511.59
# 2024-08-28 BUY EXECUTED, 2495.57
# 2024-08-29 Bracket order placed: Entry 2512.42, SL 2504.19, TP 2528.87
# 2024-08-29 BUY EXECUTED, 2512.34
# 2024-08-29 SELL EXECUTED, 2504.19
# 2024-08-29 Bracket order placed: Entry 2509.27, SL 2517.80, TP 2492.21
# 2024-08-29 SELL EXECUTED, 2509.33
# 2024-08-29 BUY EXECUTED, 2517.80
# 2024-08-30 Bracket order placed: Entry 2513.61, SL 2521.48, TP 2497.88
# 2024-08-30 SELL EXECUTED, 2513.58
# 2024-08-30 BUY EXECUTED, 2521.48
# 2024-08-30 Bracket order placed: Entry 2517.83, SL 2509.84, TP 2533.82
# 2024-08-30 BUY EXECUTED, 2517.78
# 2024-08-30 SELL EXECUTED, 2509.84
# 2024-09-03 Bracket order placed: Entry 2503.97, SL 2497.13, TP 2517.65
# 2024-09-03 BUY EXECUTED, 2504.04
# 2024-09-03 SELL EXECUTED, 2497.13
# 2024-09-04 Bracket order placed: Entry 2493.46, SL 2502.62, TP 2475.13
# 2024-09-04 SELL EXECUTED, 2493.39
# 2024-09-05 BUY EXECUTED, 2502.62
# 2024-09-06 Bracket order placed: Entry 2509.42, SL 2518.21, TP 2491.83
# 2024-09-06 SELL EXECUTED, 2509.39
# 2024-09-06 BUY EXECUTED, 2518.21
# 2024-09-09 Bracket order placed: Entry 2504.48, SL 2495.01, TP 2523.40
# 2024-09-09 BUY EXECUTED, 2504.49
# 2024-09-11 SELL EXECUTED, 2523.40
# 2024-09-11 Bracket order placed: Entry 2508.23, SL 2516.36, TP 2491.95
# 2024-09-11 SELL EXECUTED, 2508.22
# 2024-09-11 BUY EXECUTED, 2516.36
# 2024-09-11 Bracket order placed: Entry 2512.99, SL 2504.51, TP 2529.95
# 2024-09-11 BUY EXECUTED, 2513.00
# 2024-09-12 SELL EXECUTED, 2529.95
# 2024-09-17 Bracket order placed: Entry 2573.69, SL 2581.33, TP 2558.41
# 2024-09-17 SELL EXECUTED, 2573.61
# 2024-09-17 BUY EXECUTED, 2581.33
# 2024-09-17 Bracket order placed: Entry 2579.90, SL 2571.86, TP 2595.97
# 2024-09-17 BUY EXECUTED, 2579.89
# 2024-09-17 SELL EXECUTED, 2571.86
# 2024-09-17 Bracket order placed: Entry 2576.55, SL 2567.56, TP 2594.54
# 2024-09-17 BUY EXECUTED, 2576.62
# 2024-09-17 SELL EXECUTED, 2565.72
# 2024-09-17 Bracket order placed: Entry 2574.10, SL 2565.47, TP 2591.36
# 2024-09-18 BUY EXECUTED, 2574.09
# 2024-09-18 SELL EXECUTED, 2591.36
# 2024-09-18 Bracket order placed: Entry 2548.98, SL 2561.11, TP 2524.71
# 2024-09-18 SELL EXECUTED, 2548.94
# 2024-09-18 BUY EXECUTED, 2561.11
# 2024-09-27 Bracket order placed: Entry 2662.71, SL 2672.00, TP 2644.12
# 2024-09-27 SELL EXECUTED, 2662.70
# 2024-09-27 BUY EXECUTED, 2672.00
# 2024-09-29 Bracket order placed: Entry 2662.81, SL 2652.06, TP 2684.31
# 2024-09-29 BUY EXECUTED, 2662.78
# 2024-09-30 SELL EXECUTED, 2652.06
# 2024-10-01 Bracket order placed: Entry 2648.75, SL 2640.07, TP 2666.10
# 2024-10-01 BUY EXECUTED, 2648.72
# 2024-10-01 SELL EXECUTED, 2666.10
# 2024-10-02 Bracket order placed: Entry 2648.15, SL 2657.98, TP 2628.48
# 2024-10-02 SELL EXECUTED, 2648.14
# 2024-10-02 BUY EXECUTED, 2657.98
# 2024-10-02 Bracket order placed: Entry 2659.54, SL 2649.64, TP 2679.35
# 2024-10-02 BUY EXECUTED, 2659.58
# 2024-10-02 SELL EXECUTED, 2648.21
# 2024-10-02 Bracket order placed: Entry 2654.14, SL 2643.86, TP 2674.71
# 2024-10-02 BUY EXECUTED, 2654.13
# 2024-10-03 SELL EXECUTED, 2643.86
# 2024-10-03 Bracket order placed: Entry 2660.09, SL 2649.39, TP 2681.50
# 2024-10-03 BUY EXECUTED, 2660.12
# 2024-10-04 SELL EXECUTED, 2649.39
# 2024-10-04 Bracket order placed: Entry 2638.95, SL 2648.58, TP 2619.68
# 2024-10-04 SELL EXECUTED, 2638.90
# 2024-10-04 BUY EXECUTED, 2651.95
# 2024-10-04 Bracket order placed: Entry 2658.40, SL 2647.40, TP 2680.39
# 2024-10-04 BUY EXECUTED, 2658.44
# 2024-10-04 SELL EXECUTED, 2647.40
# 2024-10-07 Bracket order placed: Entry 2652.15, SL 2641.90, TP 2672.64
# 2024-10-07 BUY EXECUTED, 2652.11
# 2024-10-07 SELL EXECUTED, 2641.90
# 2024-10-08 Bracket order placed: Entry 2650.81, SL 2639.92, TP 2672.59
# 2024-10-08 BUY EXECUTED, 2650.80
# 2024-10-08 SELL EXECUTED, 2639.92
# 2024-10-10 Bracket order placed: Entry 2625.12, SL 2615.40, TP 2644.58
# 2024-10-10 BUY EXECUTED, 2625.12
# 2024-10-11 SELL EXECUTED, 2644.58
# 2024-10-14 Bracket order placed: Entry 2645.74, SL 2655.52, TP 2626.16
# 2024-10-14 SELL EXECUTED, 2645.80
# 2024-10-15 BUY EXECUTED, 2655.52

# %%
strat = results[0]
sharpe_ratio = strat.analyzers.sharperatio.get_analysis()
drawdown = strat.analyzers.drawdown.get_analysis()
trade_analysis = strat.analyzers.tradeanalyzer.get_analysis()
returns = strat.analyzers.returns.get_analysis()
print(f'Sharpe Ratio: {sharpe_ratio}')
print(f'Max Drawdown: {drawdown["max"]["drawdown"]}')
print(f'Number of Trades: {trade_analysis.total.closed}')
print(f'Winning Trades: {trade_analysis.won.total}')
print(f'Losing Trades: {trade_analysis.lost.total}')
print(f'Average Trade Return: {returns["rnorm"]}')
print(f'Total Returns: {returns["rtot"]}')
# Out:
# Sharpe Ratio: OrderedDict([('sharperatio', -8.827087906792693)])
# Max Drawdown: 17.374789601797893
# Number of Trades: 2099
# Winning Trades: 737
# Losing Trades: 1362
# Average Trade Return: -0.01027322952382351
# Total Returns: -0.19070990116731343

# %%
# %matplotlib inline
fig = cerebro.plot(iplot=True)
# plt.show()
fig
# Out:
# <div id='766a058c-9b5a-4cf2-80f7-0f85107aa84a'></div>
# [[<Figure size 640x480 with 6 Axes>]]
