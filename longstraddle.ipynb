# %%
import backtrader as bt
import yfinance as yf
import pandas as pd

# %%
class LongStraddleSimplified(bt.Strategy):
    params = (
        ('period_length', 30),       # Not used in the provided logic, keep or remove
        ('atr_lookback', 14),
        # ('atr_multiplier', 1.0),     # Not used in the provided logic, keep or remove
        ('stop_loss_percent', 2.0),
        # ('take_profit_percent', 10.0), # Replaced by risk_reward_ratio
        # ('period_comm_info', 30),   # Not used in the provided logic, keep or remove
        ('risk_per_trade', 0.02),    # 1% of portfolio value at risk
        ('risk_reward_ratio', 2.0),  # TP is 2x the risk distance
    )

    def __init__(self):
        self.atr = bt.indicators.ATR(period=self.params.atr_lookback)
        self.atr_sma = bt.indicators.SMA(self.atr, period=20)
        self.close_sma = bt.indicators.SMA(self.datas[0].close, period=20)

        # To prevent placing multiple orders while one is pending
        self.order = None
        # Calculate take profit percent based on stop loss and R:R ratio
        self.take_profit_percent = self.params.stop_loss_percent * self.params.risk_reward_ratio

        # Optional: Track open trade details if needed beyond self.position
        # self.entry_price = None
        # self.stop_loss_price = None
        # self.take_profit_price = None

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        if order.status in [order.Completed]:
            if order.isbuy():
                print(
                    f'{self.datas[0].datetime.date(0)} BUY EXECUTED, Price: {order.executed.price:.2f}, '
                    f'Cost: {order.executed.value:.2f}, Comm: {order.executed.comm:.2f}, '
                    f'Size: {order.executed.size}'
                )
                # Optional: Store entry details if needed later
                # self.entry_price = order.executed.price
                # self.stop_loss_price = order.executed.price * (1.0 - self.params.stop_loss_percent / 100.0)
                # self.take_profit_price = order.executed.price * (1.0 + self.take_profit_percent / 100.0)

            elif order.issell():
                print(
                    f'{self.datas[0].datetime.date(0)} SELL EXECUTED, Price: {order.executed.price:.2f}, '
                    f'Cost: {order.executed.value:.2f}, Comm: {order.executed.comm:.2f}, '
                    f'Size: {order.executed.size}'
                )

            self.bar_executed = len(self) # Bar number when order was executed

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            print(f'{self.datas[0].datetime.date(0)} Order Canceled/Margin/Rejected')

        # Reset order status tracking
        self.order = None

    def notify_trade(self, trade):
         if not trade.isclosed:
             return
         print(f'{self.datas[0].datetime.date(0)} TRADE PROFIT, GROSS {trade.pnl:.2f}, NET {trade.pnlcomm:.2f}')


    def next(self):
        # Wait for indicators to have enough data
        # Use max period from all indicators used in the condition + 1
        if len(self) <= max(self.params.atr_lookback, 20) + 1:
             return

        # Check if an order is pending. If so, do not send another one
        # if self.order:
        #     return

        # Check if we are already in the market
        if self.position:
            return
    
        # Calculate current indicator values
        atr_value = self.atr[0]
        atr_sma_value = self.atr_sma[0]
        close_value = self.datas[0].close[0]
        close_sma_value = self.close_sma[0]

        # Define entry condition
        high_volatility_condition = close_value > close_sma_value and atr_value > atr_sma_value

        if high_volatility_condition:
            # Calculate Stop Loss Price based on current close (potential entry)
            potential_entry = close_value
            stop_loss_price = potential_entry * (1.0 - self.params.stop_loss_percent / 100.0)
            take_profit_price = potential_entry * (1.0 + self.take_profit_percent / 100.0)

            print(f"{self.datas[0].datetime.date(0)} --- ENTRY SIGNAL ---")
            print(f"Potential Entry: {potential_entry:.2f}")
            print(f"Stop Loss Price: {stop_loss_price:.2f}")
            print(f"Take Profit Price: {take_profit_price:.2f}")

            # Place Buy order with attached Stop Loss and Take Profit (Bracket Order)
            self.order = self.buy_bracket(
                exectype=bt.Order.Market,
                transmit=True, # Transmit the main order immediately
                # The following create virtual child orders managed by backtrader
                stopprice=stop_loss_price,
                stopexec=bt.Order.Stop, # Stop Market order for SL
                limitprice=take_profit_price,
                limitexec=bt.Order.Limit # Limit order for TP
            )
            # The old way using parent/transmit=False is more complex
            # self.mainside = self.buy(size=size, exectype=bt.Order.Market)
            # self.sell(exectype=bt.Order.Stop, price=stop_loss_price, size=size, parent=self.mainside)
            # self.sell(exectype=bt.Order.Limit, price=take_profit_price, size=size, parent=self.mainside)

# %%
# Fetch S&P500 data from Yahoo Finance
# ticker = "^GSPC"  # S&P 500 ticker
# ticker = "AAPL"  # Apple ticker

# ticker = "USDJPY=X"  # USD/JPY ticker
# ticker = "^DJI"  # Dow Jones Industrial Average ticker
ticker = "^IXIC"  # NASDAQ Composite ticker
# Download Tesla data
# ticker = "TSLA"  # Tesla ticker
# Download data from Yahoo Finance
data = yf.download(ticker, start="2018-01-01", end="2023-10-01", interval="1d")

# Convert to Backtrader data feed
data['Date'] = pd.to_datetime(data.index)
data.set_index('Date', inplace=True)

# Clean columns to match Backtrader's expectations
data = data[['Open', 'High', 'Low', 'Close', 'Volume']]
data.columns = ['open', 'high', 'low', 'close', 'volume']
data['openinterest'] = 0  # Backtrader requires this column
data['close'] = data['close'].astype(float)
data['open'] = data['open'].astype(float)
data['high'] = data['high'].astype(float)
data['low'] = data['low'].astype(float)
data['volume'] = data['volume'].astype(float)
data['openinterest'] = data['openinterest'].astype(float)
data['datetime'] = data.index
data['datetime'] = pd.to_datetime(data['datetime'])
# data['datetime'] = data['datetime'].apply(lambda x: x.timestamp())
# data['datetime'] = pd.to_datetime(data['datetime'], unit='s')
# data['datetime'] = data['datetime'].dt.tz_localize('UTC').dt.tz_convert('America/New_York')

data_feed = bt.feeds.PandasData(dataname=data,
                                # datetime=0, open=1, high=2, low=3, close=4, volume=5, openinterest=-1
                                )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
cerebro = bt.Cerebro()

# Add Strategy
cerebro.addstrategy(LongStraddleSimplified)

cerebro.adddata(data_feed)
cerebro.addsizer(bt.sizers.PercentSizer, percents=2)

# Set initial capital
cerebro.broker.setcash(100000.0)

# Set commission - Simplified for example, adjust as needed
cerebro.broker.setcommission(commission=0.001)

# Analyzer for performance metrics
cerebro.addanalyzer(bt.analyzers.Returns, _name='returns')
cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe', riskfreerate=0.0)
cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')

# %%
# Run Backtest
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
results = cerebro.run()
print('Final Portfolio Value:   %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2018-02-20 --- ENTRY SIGNAL ---
# Potential Entry: 7234.31
# Stop Loss Price: 7089.62
# Take Profit Price: 7523.68
# 2018-02-21 BUY EXECUTED, Price: 7258.48, Cost: 2006.68, Comm: 2.01, Size: 0.27646036509372013
# 2018-03-02 SELL EXECUTED, Price: 7089.62, Cost: 2006.68, Comm: 1.96, Size: -0.27646036509372013
# 2018-03-02 Order Canceled/Margin/Rejected
# 2018-03-02 TRADE PROFIT, GROSS -46.68, NET -50.65
# 2018-03-02 --- ENTRY SIGNAL ---
# Potential Entry: 7257.87
# Stop Loss Price: 7112.71
# Take Profit Price: 7548.18
# 2019-01-15 Order Canceled/Margin/Rejected
# 2019-01-15 TRADE PROFIT, GROSS 74.38, NET 70.30
# 2019-03-21 --- ENTRY SIGNAL ---
# Potential Entry: 7838.96
# Stop Loss Price: 7682.18
# Take Profit Price: 8152.52
# 2019-03-22 BUY EXECUTED, Price: 7800.25, Cost: 1989.53, Comm: 1.99, Size: 0.25505931722707514
# 2019-03-25 SELL EXECUTED, Price: 7618.98, Cost: 1989.53, Comm: 1.94, Size: -0.25505931722707514
# 2019-03-25 Order Canceled/Margin/Rejected
# 2019-03-25 TRADE PROFIT, GROSS -46.23, NET -50.17
# 2019-03-25 --- ENTRY SIGNAL ---
# Potential Entry: 7637.54
# Stop Loss Price: 7484.79
# Take Profit Price: 7943.04
# 2019-03-26 BUY EXECUTED, Price: 7700.00, Cost: 2014.74, Comm: 2.01, Size: 0.26165446160314626
# 2019-04-08 SELL EXECUTED, Price: 7943.04, Cost: 2014.74, Comm: 2.08, Size: -0.26165446160314626
# 2019-04-08 Order Canceled/Margin/Rejected
# 2019-04-08 TRADE PROFIT, GROSS 63.59, NET 59.50
# 2019-05-02 --- ENTRY SIGNAL ---
# Potential Entry: 8036.77
# Stop Loss Price: 7876.03
# Take Profit Price: 8358.24
# 2019-05-03 BUY EXECUTED, Price: 8092.88, Cost: 2013.55, Comm: 2.01, Size: 0.2488047336422014
# 2019-05-09 SELL EXECUTED, Price: 7853.21, Cost: 2013.55, Comm: 1.95, Size: -0.2488047336422014
# 2019-05-09 Order Canceled/Margin/Rejected
# 2019-05-09 TRADE PROFIT, GROSS -59.63, NET -63.60
# 2019-06-07 --- ENTRY SIGNAL ---
# Potential Entry: 7742.10
# Stop Loss Price: 7587.26
# Take Profit Price: 8051.78
# 2019-06-10 BUY EXECUTED, Price: 7798.87, Cost: 2012.97, Comm: 2.01, Size: 0.25811012895375
# 2019-06-20 SELL EXECUTED, Price: 8087.45, Cost: 2012.97, Comm: 2.09, Size: -0.25811012895375
# 2019-06-20 Order Canceled/Margin/Rejected
# 2019-06-20 TRADE PROFIT, GROSS 74.49, NET 70.39
# 2019-08-21 --- ENTRY SIGNAL ---
# Potential Entry: 8020.21
# Stop Loss Price: 7859.81
# Take Profit Price: 8341.02
# 2019-08-22 BUY EXECUTED, Price: 8038.79, Cost: 2004.35, Comm: 2.00, Size: 0.24933538707071712
# 2019-08-23 SELL EXECUTED, Price: 7859.81, Cost: 2004.35, Comm: 1.96, Size: -0.24933538707071712
# 2019-08-23 Order Canceled/Margin/Rejected
# 2019-08-23 TRADE PROFIT, GROSS -44.63, NET -48.59
# 2019-08-29 --- ENTRY SIGNAL ---
# Potential Entry: 7973.39
# Stop Loss Price: 7813.92
# Take Profit Price: 8292.33
# 2019-08-30 BUY EXECUTED, Price: 8015.16, Cost: 2009.22, Comm: 2.01, Size: 0.25067760347785134
# 2019-10-02 SELL EXECUTED, Price: 7813.92, Cost: 2009.22, Comm: 1.96, Size: -0.25067760347785134
# 2019-10-02 Order Canceled/Margin/Rejected
# 2019-10-02 TRADE PROFIT, GROSS -50.45, NET -54.41
# 2019-10-11 --- ENTRY SIGNAL ---
# Potential Entry: 8057.04
# Stop Loss Price: 7895.90
# Take Profit Price: 8379.32
# 2019-10-14 BUY EXECUTED, Price: 8044.35, Cost: 1994.52, Comm: 1.99, Size: 0.24793994384437315
# 2019-11-01 SELL EXECUTED, Price: 8379.32, Cost: 1994.52, Comm: 2.08, Size: -0.24793994384437315
# 2019-11-01 Order Canceled/Margin/Rejected
# 2019-11-01 TRADE PROFIT, GROSS 83.05, NET 78.98
# 2019-12-04 --- ENTRY SIGNAL ---
# Potential Entry: 8566.67
# Stop Loss Price: 8395.34
# Take Profit Price: 8909.34
# 2019-12-05 BUY EXECUTED, Price: 8587.93, Cost: 2004.20, Comm: 2.00, Size: 0.23337442528958063
# 2019-12-20 SELL EXECUTED, Price: 8911.84, Cost: 2004.20, Comm: 2.08, Size: -0.23337442528958063
# 2019-12-20 Order Canceled/Margin/Rejected
# 2019-12-20 TRADE PROFIT, GROSS 75.59, NET 71.51
# 2020-01-03 --- ENTRY SIGNAL ---
# Potential Entry: 9020.77
# Stop Loss Price: 8840.35
# Take Profit Price: 9381.60
# 2020-01-06 BUY EXECUTED, Price: 8943.50, Cost: 1983.53, Comm: 1.98, Size: 0.2217850516732965
# 2020-01-17 SELL EXECUTED, Price: 9392.37, Cost: 1983.53, Comm: 2.08, Size: -0.2217850516732965
# 2020-01-17 Order Canceled/Margin/Rejected
# 2020-01-17 TRADE PROFIT, GROSS 99.55, NET 95.49
# 2020-01-17 --- ENTRY SIGNAL ---
# Potential Entry: 9388.94
# Stop Loss Price: 9201.16
# Take Profit Price: 9764.50
# 2020-01-21 BUY EXECUTED, Price: 9361.07, Cost: 1996.64, Comm: 2.00, Size: 0.2132915394258717
# 2020-01-27 SELL EXECUTED, Price: 9092.46, Cost: 1996.64, Comm: 1.94, Size: -0.2132915394258717
# 2020-01-27 Order Canceled/Margin/Rejected
# 2020-01-27 TRADE PROFIT, GROSS -57.29, NET -61.23
# 2020-01-28 --- ENTRY SIGNAL ---
# Potential Entry: 9269.68
# Stop Loss Price: 9084.29
# Take Profit Price: 9640.47
# 2020-01-29 BUY EXECUTED, Price: 9318.26, Cost: 2011.85, Comm: 2.01, Size: 0.21590357588938477
# 2020-02-11 SELL EXECUTED, Price: 9680.89, Cost: 2011.85, Comm: 2.09, Size: -0.21590357588938477
# 2020-02-11 Order Canceled/Margin/Rejected
# 2020-02-11 TRADE PROFIT, GROSS 78.29, NET 74.19
# 2020-02-11 --- ENTRY SIGNAL ---
# Potential Entry: 9638.94
# Stop Loss Price: 9446.16
# Take Profit Price: 10024.50
# 2020-02-12 BUY EXECUTED, Price: 9688.60, Cost: 2013.16, Comm: 2.01, Size: 0.20778640853452213
# 2020-02-24 SELL EXECUTED, Price: 9188.44, Cost: 2013.16, Comm: 1.91, Size: -0.20778640853452213
# 2020-02-24 Order Canceled/Margin/Rejected
# 2020-02-24 TRADE PROFIT, GROSS -103.93, NET -107.85
# 2020-03-30 --- ENTRY SIGNAL ---
# Potential Entry: 7774.15
# Stop Loss Price: 7618.67
# Take Profit Price: 8085.12
# 2020-03-31 BUY EXECUTED, Price: 7740.06, Cost: 1991.91, Comm: 1.99, Size: 0.25735081850169583
# 2020-08-05 Order Canceled/Margin/Rejected
# 2020-08-05 TRADE PROFIT, GROSS 87.07, NET 82.99
# 2020-09-03 --- ENTRY SIGNAL ---
# Potential Entry: 11458.10
# Stop Loss Price: 11228.94
# Take Profit Price: 11916.42
# 2020-09-04 BUY EXECUTED, Price: 11396.24, Cost: 1990.90, Comm: 1.99, Size: 0.1746980061817503
# 2020-09-08 SELL EXECUTED, Price: 10900.70, Cost: 1990.90, Comm: 1.90, Size: -0.1746980061817503
# 2020-09-08 Order Canceled/Margin/Rejected
# 2020-09-08 TRADE PROFIT, GROSS -86.57, NET -90.47
# 2020-09-29 --- ENTRY SIGNAL ---
# Potential Entry: 11085.25
# Stop Loss Price: 10863.55
# Take Profit Price: 11528.66
# 2020-09-30 BUY EXECUTED, Price: 11092.90, Cost: 2001.28, Comm: 2.00, Size: 0.18041071285111435
# 2020-10-09 SELL EXECUTED, Price: 11528.66, Cost: 2001.28, Comm: 2.08, Size: -0.18041071285111435
# 2020-10-09 Order Canceled/Margin/Rejected
# 2020-10-09 TRADE PROFIT, GROSS 78.62, NET 74.53
# 2020-11-04 --- ENTRY SIGNAL ---
# Potential Entry: 11590.78
# Stop Loss Price: 11358.96
# Take Profit Price: 12054.41
# 2020-11-05 BUY EXECUTED, Price: 11816.33, Cost: 2040.33, Comm: 2.04, Size: 0.17267073467157734
# 2020-11-09 SELL EXECUTED, Price: 12054.41, Cost: 2040.33, Comm: 2.08, Size: -0.17267073467157734
# 2020-11-09 Order Canceled/Margin/Rejected
# 2020-11-09 TRADE PROFIT, GROSS 41.11, NET 36.99
# 2020-11-09 --- ENTRY SIGNAL ---
# Potential Entry: 11713.78
# Stop Loss Price: 11479.50
# Take Profit Price: 12182.33
# 2020-11-10 BUY EXECUTED, Price: 11622.44, Cost: 1986.52, Comm: 1.99, Size: 0.17092076654607252
# 2020-11-27 SELL EXECUTED, Price: 12182.33, Cost: 1986.52, Comm: 2.08, Size: -0.17092076654607252
# 2020-11-27 Order Canceled/Margin/Rejected
# 2020-11-27 TRADE PROFIT, GROSS 95.70, NET 91.63
# 2021-01-06 --- ENTRY SIGNAL ---
# Potential Entry: 12740.79
# Stop Loss Price: 12485.97
# Take Profit Price: 13250.42
# 2021-01-07 BUY EXECUTED, Price: 12867.34, Cost: 2023.87, Comm: 2.02, Size: 0.15728701775258094
# 2021-01-20 SELL EXECUTED, Price: 13342.55, Cost: 2023.87, Comm: 2.10, Size: -0.15728701775258094
# 2021-01-20 Order Canceled/Margin/Rejected
# 2021-01-20 TRADE PROFIT, GROSS 74.74, NET 70.62
# 2021-01-20 --- ENTRY SIGNAL ---
# Potential Entry: 13457.25
# Stop Loss Price: 13188.10
# Take Profit Price: 13995.54
# 2021-01-21 BUY EXECUTED, Price: 13521.48, Cost: 2014.94, Comm: 2.01, Size: 0.14901806139438625
# 2021-01-29 SELL EXECUTED, Price: 13188.10, Cost: 2014.94, Comm: 1.97, Size: -0.14901806139438625
# 2021-01-29 Order Canceled/Margin/Rejected
# 2021-01-29 TRADE PROFIT, GROSS -49.68, NET -53.66
# 2021-02-01 --- ENTRY SIGNAL ---
# Potential Entry: 13403.39
# 2021-08-30 SELL EXECUTED, Price: 15217.23, Cost: 2005.73, Comm: 2.08, Size: -0.13688443953243257
# 2021-08-30 Order Canceled/Margin/Rejected
# 2021-08-30 TRADE PROFIT, GROSS 77.27, NET 73.18
# 2021-08-30 --- ENTRY SIGNAL ---
# Potential Entry: 15265.89
# Stop Loss Price: 14960.57
# Take Profit Price: 15876.53
# 2021-08-31 BUY EXECUTED, Price: 15262.88, Cost: 2003.95, Comm: 2.00, Size: 0.1312959822072247
# 2021-09-20 SELL EXECUTED, Price: 14758.14, Cost: 2003.95, Comm: 1.94, Size: -0.1312959822072247
# 2021-09-20 Order Canceled/Margin/Rejected
# 2021-09-20 TRADE PROFIT, GROSS -66.27, NET -70.21
# 2021-10-14 --- ENTRY SIGNAL ---
# Potential Entry: 14823.43
# Stop Loss Price: 14526.96
# Take Profit Price: 15416.37
# 2021-10-15 BUY EXECUTED, Price: 14891.24, Cost: 2012.11, Comm: 2.01, Size: 0.13512026419001733
# 2021-10-28 SELL EXECUTED, Price: 15416.37, Cost: 2012.11, Comm: 2.08, Size: -0.13512026419001733
# 2021-10-28 Order Canceled/Margin/Rejected
# 2021-10-28 TRADE PROFIT, GROSS 70.96, NET 66.86
# 2021-11-22 --- ENTRY SIGNAL ---
# Potential Entry: 15854.76
# Stop Loss Price: 15537.66
# Take Profit Price: 16488.95
# 2021-11-23 BUY EXECUTED, Price: 15809.50, Cost: 1998.56, Comm: 2.00, Size: 0.12641521957925636
# 2021-11-26 SELL EXECUTED, Price: 15537.66, Cost: 1998.56, Comm: 1.96, Size: -0.12641521957925636
# 2021-11-26 Order Canceled/Margin/Rejected
# 2021-11-26 TRADE PROFIT, GROSS -34.36, NET -38.33
# 2021-12-08 --- ENTRY SIGNAL ---
# Potential Entry: 15786.99
# Stop Loss Price: 15471.25
# Take Profit Price: 16418.47
# 2021-12-09 BUY EXECUTED, Price: 15720.54, Cost: 1995.08, Comm: 2.00, Size: 0.12690933290760015
# 2021-12-13 SELL EXECUTED, Price: 15471.25, Cost: 1995.08, Comm: 1.96, Size: -0.12690933290760015
# 2021-12-13 Order Canceled/Margin/Rejected
# 2021-12-13 TRADE PROFIT, GROSS -31.64, NET -35.60
# 2021-12-22 --- ENTRY SIGNAL ---
# Potential Entry: 15521.89
# Stop Loss Price: 15211.45
# Take Profit Price: 16142.77
# 2021-12-23 BUY EXECUTED, Price: 15544.79, Cost: 2005.76, Comm: 2.01, Size: 0.12903097048612228
# 2022-01-05 SELL EXECUTED, Price: 15211.45, Cost: 2005.76, Comm: 1.96, Size: -0.12903097048612228
# 2022-01-05 Order Canceled/Margin/Rejected
# 2022-01-05 TRADE PROFIT, GROSS -43.01, NET -46.98
# 2022-02-02 --- ENTRY SIGNAL ---
# Potential Entry: 14417.55
# Stop Loss Price: 14129.20
# Take Profit Price: 14994.25
# 2022-02-03 BUY EXECUTED, Price: 14045.83, Cost: 1950.25, Comm: 1.95, Size: 0.13884917500504443
# 2022-02-04 SELL EXECUTED, Price: 13958.48, Cost: 1950.25, Comm: 1.94, Size: -0.13884917500504443
# 2022-02-04 Order Canceled/Margin/Rejected
# Take Profit Price: 12185.97
# 2023-03-17 BUY EXECUTED, Price: 11696.34, Cost: 1997.81, Comm: 2.00, Size: 0.17080655397639607
# 2023-03-31 SELL EXECUTED, Price: 12185.97, Cost: 1997.81, Comm: 2.08, Size: -0.17080655397639607
# 2023-03-31 Order Canceled/Margin/Rejected
# 2023-03-31 TRADE PROFIT, GROSS 83.63, NET 79.55
# 2023-05-26 --- ENTRY SIGNAL ---
# Potential Entry: 12975.69
# Stop Loss Price: 12716.18
# Take Profit Price: 13494.72
# 2023-05-30 BUY EXECUTED, Price: 13109.10, Cost: 2023.57, Comm: 2.02, Size: 0.15436398834376186
# 2023-06-13 SELL EXECUTED, Price: 13566.53, Cost: 2023.57, Comm: 2.09, Size: -0.15436398834376186
# 2023-06-13 Order Canceled/Margin/Rejected
# 2023-06-13 TRADE PROFIT, GROSS 70.61, NET 66.49
# 2023-06-13 --- ENTRY SIGNAL ---
# Potential Entry: 13573.32
# Stop Loss Price: 13301.85
# Take Profit Price: 14116.25
# 2023-06-14 BUY EXECUTED, Price: 13570.56, Cost: 2003.90, Comm: 2.00, Size: 0.14766535684686002
# 2023-07-13 SELL EXECUTED, Price: 14116.25, Cost: 2003.90, Comm: 2.08, Size: -0.14766535684686002
# 2023-07-13 Order Canceled/Margin/Rejected
# 2023-07-13 TRADE PROFIT, GROSS 80.58, NET 76.49
# 2023-07-20 --- ENTRY SIGNAL ---
# Potential Entry: 14063.31
# Stop Loss Price: 13782.04
# Take Profit Price: 14625.84
# 2023-07-21 BUY EXECUTED, Price: 14148.18, Cost: 2017.94, Comm: 2.02, Size: 0.14262923037578998
# 2023-08-08 SELL EXECUTED, Price: 13782.04, Cost: 2017.94, Comm: 1.97, Size: -0.14262923037578998
# 2023-08-08 Order Canceled/Margin/Rejected
# 2023-08-08 TRADE PROFIT, GROSS -52.22, NET -56.21
# 2023-08-28 --- ENTRY SIGNAL ---
# Potential Entry: 13705.13
# Stop Loss Price: 13431.03
# Take Profit Price: 14253.34
# 2023-08-29 BUY EXECUTED, Price: 13687.23, Cost: 2002.10, Comm: 2.00, Size: 0.14627478393632012
# 2023-09-21 SELL EXECUTED, Price: 13328.06, Cost: 2002.10, Comm: 1.95, Size: -0.14627478393632012
# 2023-09-21 Order Canceled/Margin/Rejected
# 2023-09-21 TRADE PROFIT, GROSS -52.54, NET -56.49
# Final Portfolio Value:   100179.26

# %%
# Extract Analyzers
returns_analyzer = results[0].analyzers.returns.get_analysis()
sharpe_analyzer = results[0].analyzers.sharpe.get_analysis()
drawdown_analyzer = results[0].analyzers.drawdown.get_analysis()

print('Returns:', returns_analyzer['rtot'])
print('Sharpe Ratio:', sharpe_analyzer['sharperatio'])
print('Drawdown:', drawdown_analyzer['drawdown'])
print('Max Drawdown:', drawdown_analyzer['max']['drawdown'])
# Optional: Plot the backtest result
cerebro.plot()
# Out:
# Returns: 0.016325308153431087
# Sharpe Ratio: 0.32820474882492107
# Drawdown: 0.7660094269858404
# Max Drawdown: 1.5773378529087687
# <div id='16f21088-a6ce-4cbc-bef3-2e0cbb724977'></div>
# [[<Figure size 640x480 with 5 Axes>]]
